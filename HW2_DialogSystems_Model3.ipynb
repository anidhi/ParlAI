# %% [markdown]
# <a href="https://colab.research.google.com/github/anidhi/ParlAI/blob/master/HW2_DialogSystems_Model3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %ls /content/gdrive/'My Drive'

# %%
# !pip install torch
import torch
model_save_name = 'HW2_model3'
path = F"/content/gdrive/My Drive/{model_save_name}"
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)

# %%
# !git clone https://github.com/facebookresearch/ParlAI
# !cd ParlAI; python setup.py develop install
# Out:
# Cloning into 'ParlAI'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 28513 (delta 99), reused 100 (delta 60), pack-reused 28351
# Receiving objects: 100% (28513/28513), 28.64 MiB | 35.17 MiB/s, done.
# Resolving deltas: 100% (20227/20227), done.
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/parlai.egg-link (link to .)
# Adding parlai 0.1.0 to easy-install.pth file
#
# Installed /content/ParlAI
# Processing dependencies for parlai==0.1.0
# Searching for websocket-server==0.4
# Reading https://pypi.org/simple/websocket-server/
# Downloading https://files.pythonhosted.org/packages/74/64/e86581ee7775a2e08aca530b41e1a1e3ee6b320233b1eff301dcb86d1636/websocket_server-0.4.tar.gz#sha256=91cd4b565d1e1b00ef107abcb2840a8090868b19543f3b38e1962d5f975d0c04
# Best match: websocket-server 0.4
# Processing websocket_server-0.4.tar.gz
# Writing /tmp/easy_install-_zimc2wm/websocket_server-0.4/setup.cfg
# Running websocket_server-0.4/setup.py -q bdist_egg --dist-dir /tmp/easy_install-_zimc2wm/websocket_server-0.4/egg-dist-tmp-3byn1v0g
# zip_safe flag not set; analyzing archive contents...
# Moving websocket_server-0.4-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding websocket-server 0.4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/websocket_server-0.4-py3.6.egg
# Searching for websocket-client==0.56.0
# Reading https://pypi.org/simple/websocket-client/
# Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl#sha256=1151d5fb3a62dc129164292e1227655e4bbc5dd5340a5165dfae61128ec50aa9
# Best match: websocket-client 0.56.0
# Processing websocket_client-0.56.0-py2.py3-none-any.whl
# Installing websocket_client-0.56.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding websocket-client 0.56.0 to easy-install.pth file
# Installing wsdump.py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/websocket_client-0.56.0-py3.6.egg
# Searching for Unidecode==1.1.1
# Reading https://pypi.org/simple/Unidecode/
# Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl#sha256=1d7a042116536098d05d599ef2b8616759f02985c85b4fef50c78a5aaf10822a
# Best match: Unidecode 1.1.1
# Processing Unidecode-1.1.1-py2.py3-none-any.whl
# Installing Unidecode-1.1.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding Unidecode 1.1.1 to easy-install.pth file
# Installing unidecode script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/Unidecode-1.1.1-py3.6.egg
# Searching for tqdm==4.36.1
# Reading https://pypi.org/simple/tqdm/
# Downloading https://files.pythonhosted.org/packages/e1/c1/bc1dba38b48f4ae3c4428aea669c5e27bd5a7642a74c8348451e0bd8ff86/tqdm-4.36.1-py2.py3-none-any.whl#sha256=dd3fcca8488bb1d416aa7469d2f277902f26260c45aa86b667b074cd44b3b115
# Best match: tqdm 4.36.1
# Processing tqdm-4.36.1-py2.py3-none-any.whl
# Installing tqdm-4.36.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding tqdm 4.36.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/tqdm-4.36.1-py3.6.egg
# Searching for sphinx-autodoc-typehints==1.10.3
# Reading https://pypi.org/simple/sphinx-autodoc-typehints/
# Downloading https://files.pythonhosted.org/packages/00/83/87b8890a93b3994b49960716009c1effb6f7a1fef3a1ec553fda2a7c84de/sphinx_autodoc_typehints-1.10.3-py3-none-any.whl#sha256=27c9e6ef4f4451766ab8d08b2d8520933b97beb21c913f3df9ab2e59b56e6c6c
# Best match: sphinx-autodoc-typehints 1.10.3
# Processing sphinx_autodoc_typehints-1.10.3-py3-none-any.whl
# Installing sphinx_autodoc_typehints-1.10.3-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinx-autodoc-typehints 1.10.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinx_autodoc_typehints-1.10.3-py3.6.egg
# Searching for sphinx_rtd_theme==0.4.3
# Reading https://pypi.org/simple/sphinx_rtd_theme/
# Downloading https://files.pythonhosted.org/packages/60/b4/4df37087a1d36755e3a3bfd2a30263f358d2dea21938240fa02313d45f51/sphinx_rtd_theme-0.4.3-py2.py3-none-any.whl#sha256=00cf895504a7895ee433807c62094cf1e95f065843bf3acd17037c3e9a2becd4
# Best match: sphinx-rtd-theme 0.4.3
# Processing sphinx_rtd_theme-0.4.3-py2.py3-none-any.whl
# Installing sphinx_rtd_theme-0.4.3-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinx-rtd-theme 0.4.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinx_rtd_theme-0.4.3-py3.6.egg
# Searching for Sphinx==2.2.0
# Reading https://pypi.org/simple/Sphinx/
# Downloading https://files.pythonhosted.org/packages/8e/4c/95a21788db2e1653e931420f561015a0bbc9bd4660c4520467ab9e733eb2/Sphinx-2.2.0-py3-none-any.whl#sha256=839a3ed6f6b092bb60f492024489cc9e6991360fb9f52ed6361acd510d261069
# Best match: Sphinx 2.2.0
# Processing Sphinx-2.2.0-py3-none-any.whl
# Installing Sphinx-2.2.0-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding Sphinx 2.2.0 to easy-install.pth file
# Installing sphinx-apidoc script to /usr/local/bin
# Installing sphinx-autogen script to /usr/local/bin
# Installing sphinx-build script to /usr/local/bin
# Installing sphinx-quickstart script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/Sphinx-2.2.0-py3.6.egg
# Searching for sh==1.12.14
# Reading https://pypi.org/simple/sh/
# Downloading https://files.pythonhosted.org/packages/4a/22/17b22ef5b049f12080f5815c41bf94de3c229217609e469001a8f80c1b3d/sh-1.12.14-py2.py3-none-any.whl#sha256=ae3258c5249493cebe73cb4e18253a41ed69262484bad36fdb3efcb8ad8870bb
# Best match: sh 1.12.14
# Processing sh-1.12.14-py2.py3-none-any.whl
# Installing sh-1.12.14-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sh 1.12.14 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sh-1.12.14-py3.6.egg
# Searching for requests-mock==1.7.0
# Reading https://pypi.org/simple/requests-mock/
# Downloading https://files.pythonhosted.org/packages/8c/f1/66c54a412543b29454102ae74b1454fce2d307b1c36e6bd2e9818394df88/requests_mock-1.7.0-py2.py3-none-any.whl#sha256=510df890afe08d36eca5bb16b4aa6308a6f85e3159ad3013bac8b9de7bd5a010
# Best match: requests-mock 1.7.0
# Processing requests_mock-1.7.0-py2.py3-none-any.whl
# Installing requests_mock-1.7.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding requests-mock 1.7.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/requests_mock-1.7.0-py3.6.egg
# Searching for requests==2.22.0
# Reading https://pypi.org/simple/requests/
# Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl#sha256=9cf5292fcd0f598c671cfc1e0d7d1a7f13bb8085e9a590f48c010551dc6c4b31
# Best match: requests 2.22.0
# Processing requests-2.22.0-py2.py3-none-any.whl
# Installing requests-2.22.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding requests 2.22.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/requests-2.22.0-py3.6.egg
# Searching for recommonmark==0.6.0
# Reading https://pypi.org/simple/recommonmark/
# Downloading https://files.pythonhosted.org/packages/94/de/334aaf73df8c0e77fb07f883d1e274344526196c137ef3479cb5e5aef086/recommonmark-0.6.0-py2.py3-none-any.whl#sha256=2ec4207a574289355d5b6ae4ae4abb29043346ca12cdd5f07d374dc5987d2852
# Best match: recommonmark 0.6.0
# Processing recommonmark-0.6.0-py2.py3-none-any.whl
# Installing recommonmark-0.6.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding recommonmark 0.6.0 to easy-install.pth file
# Installing cm2html script to /usr/local/bin
# Installing cm2latex script to /usr/local/bin
# Installing cm2man script to /usr/local/bin
# Installing cm2pseudoxml script to /usr/local/bin
# Installing cm2xetex script to /usr/local/bin
# Installing cm2xml script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/recommonmark-0.6.0-py3.6.egg
# Searching for regex==2019.8.19
# Reading https://pypi.org/simple/regex/
# Downloading https://files.pythonhosted.org/packages/6f/a6/99eeb5904ab763db87af4bd71d9b1dfdd9792681240657a4c0a599c10a81/regex-2019.08.19.tar.gz#sha256=587b62d48ca359d2d4f02d486f1f0aa9a20fbaf23a9d4198c4bed72ab2f6c849
# Best match: regex 2019.8.19
# Processing regex-2019.08.19.tar.gz
# Writing /tmp/easy_install-6h4s2lsc/regex-2019.08.19/setup.cfg
# Running regex-2019.08.19/setup.py -q bdist_egg --dist-dir /tmp/easy_install-6h4s2lsc/regex-2019.08.19/egg-dist-tmp-ghexnssf
# BASE_DIR is /tmp/easy_install-6h4s2lsc/regex-2019.08.19
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:476: UserWarning: Normalizing '2019.08.19' to '2019.8.19'
#   normalized_version,
# regex_3/_regex.c: In function ‘folded_char_at’:
# regex_3/_regex.c:10625:9: warning: variable ‘folded_len’ set but not used [-Wunused-but-set-variable]
#      int folded_len;
#          ^~~~~~~~~~
# regex_3/_regex.c: In function ‘fuzzy_match_group_fld’:
# regex_3/_regex.c:11503:10: warning: ‘data.new_text_pos’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (!record_fuzzy(state, data.fuzzy_type, data.new_text_pos - data.step))
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# regex_3/_regex.c: In function ‘fuzzy_match_string_fld’:
# regex_3/_regex.c:11270:10: warning: ‘data.new_text_pos’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (!record_fuzzy(state, data.fuzzy_type, data.new_text_pos - data.step))
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# regex_3/_regex.c: In function ‘basic_match’:
# regex_3/_regex.c:11608:10: warning: ‘data.new_text_pos’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (!record_fuzzy(state, data.fuzzy_type, data.new_text_pos - data.step))
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# regex_3/_regex.c:11522:18: note: ‘data.new_text_pos’ was declared here
#      RE_FuzzyData data;
#                   ^~~~
# regex_3/_regex.c:11369:10: warning: ‘data.new_text_pos’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (!record_fuzzy(state, data.fuzzy_type, data.new_text_pos - data.step))
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# regex_3/_regex.c:11288:18: note: ‘data.new_text_pos’ was declared here
#      RE_FuzzyData data;
#                   ^~~~
# zip_safe flag not set; analyzing archive contents...
# regex.__pycache__._regex.cpython-36: module references __file__
# creating /usr/local/lib/python3.6/dist-packages/regex-2019.8.19-py3.6-linux-x86_64.egg
# Extracting regex-2019.8.19-py3.6-linux-x86_64.egg to /usr/local/lib/python3.6/dist-packages
# Adding regex 2019.8.19 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/regex-2019.8.19-py3.6-linux-x86_64.egg
# Searching for pyzmq==18.1.0
# Reading https://pypi.org/simple/pyzmq/
# Downloading https://files.pythonhosted.org/packages/75/89/6f0ea51ffa9c2c00c0ab0460f137b16a5ab5b47e3b060c5b1fc9ca425836/pyzmq-18.1.0-cp36-cp36m-manylinux1_x86_64.whl#sha256=b645a49376547b3816433a7e2d2a99135c8e651e50497e7ecac3bd126e4bea16
# Best match: pyzmq 18.1.0
# Processing pyzmq-18.1.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing pyzmq-18.1.0-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# Adding pyzmq 18.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pyzmq-18.1.0-py3.6-linux-x86_64.egg
# Searching for py-rouge==1.1
# Reading https://pypi.org/simple/py-rouge/
# Downloading https://files.pythonhosted.org/packages/9c/1d/0bdbaf559fb7afe32308ebc84a2028600988212d7eb7fb9f69c4e829e4a0/py_rouge-1.1-py3-none-any.whl#sha256=9ae2a859a9edc6d25f3908e48706f7d82d6e78ea18954560c4cb21897dc1d270
# Best match: py-rouge 1.1
# Processing py_rouge-1.1-py3-none-any.whl
# Installing py_rouge-1.1-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding py-rouge 1.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/py_rouge-1.1-py3.6.egg
# Searching for py-gfm==0.1.4
# Reading https://pypi.org/simple/py-gfm/
# Downloading https://files.pythonhosted.org/packages/21/e0/be291e07b5e72e83285e4c0caf8060db0ab8d26f60bda254651e41493652/py_gfm-0.1.4-py2.py3-none-any.whl#sha256=d873541bcae194cc3b5053858719668834d3f1829342f0566ab3a48d0d744d58
# Best match: py-gfm 0.1.4
# Processing py_gfm-0.1.4-py2.py3-none-any.whl
# Installing py_gfm-0.1.4-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding py-gfm 0.1.4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/py_gfm-0.1.4-py3.6.egg
# Searching for pexpect==4.7.0
# Reading https://pypi.org/simple/pexpect/
# Downloading https://files.pythonhosted.org/packages/0e/3e/377007e3f36ec42f1b84ec322ee12141a9e10d808312e5738f52f80a232c/pexpect-4.7.0-py2.py3-none-any.whl#sha256=2094eefdfcf37a1fdbfb9aa090862c1a4878e5c7e0e7e7088bdb511c558e5cd1
# Best match: pexpect 4.7.0
# Processing pexpect-4.7.0-py2.py3-none-any.whl
# Installing pexpect-4.7.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pexpect 4.7.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pexpect-4.7.0-py3.6.egg
# Searching for pytest==5.3.2
# Reading https://pypi.org/simple/pytest/
# Downloading https://files.pythonhosted.org/packages/19/cf/711f1d887cb92c5155c9a1eb338f1b5d2411b50e4492a3b20e4a188a22b2/pytest-5.3.2-py3-none-any.whl#sha256=e41d489ff43948babd0fad7ad5e49b8735d5d55e26628a58673c39ff61d95de4
# Best match: pytest 5.3.2
# Processing pytest-5.3.2-py3-none-any.whl
# Installing pytest-5.3.2-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pytest 5.3.2 to easy-install.pth file
# Installing py.test script to /usr/local/bin
# Installing pytest script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pytest-5.3.2-py3.6.egg
# Searching for nltk==3.4.5
# Reading https://pypi.org/simple/nltk/
# Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip#sha256=bed45551259aa2101381bbdd5df37d44ca2669c5c3dad72439fa459b29137d94
# Best match: nltk 3.4.5
# Processing nltk-3.4.5.zip
# Writing /tmp/easy_install-h9fdxf06/nltk-3.4.5/setup.cfg
# Running nltk-3.4.5/setup.py -q bdist_egg --dist-dir /tmp/easy_install-h9fdxf06/nltk-3.4.5/egg-dist-tmp-ztehypqg
# warning: no files found matching 'README.txt'
# warning: no files found matching 'Makefile' under directory '*.txt'
# warning: no previously-included files matching '*~' found anywhere in distribution
# creating /usr/local/lib/python3.6/dist-packages/nltk-3.4.5-py3.6.egg
# Extracting nltk-3.4.5-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding nltk 3.4.5 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/nltk-3.4.5-py3.6.egg
# Searching for h5py==2.10.0
# Reading https://pypi.org/simple/h5py/
# Downloading https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl#sha256=d3c59549f90a891691991c17f8e58c8544060fdf3ccdea267100fa5f561ff62f
# Best match: h5py 2.10.0
# Processing h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# Adding h5py 2.10.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/h5py-2.10.0-py3.6-linux-x86_64.egg
# Searching for GitPython==3.0.3
# Reading https://pypi.org/simple/GitPython/
# Downloading https://files.pythonhosted.org/packages/ff/f8/05f58bd7852dad7edcf70a8de953b4fa39f61cdc13812ae62118be6ffa23/GitPython-3.0.3-py3-none-any.whl#sha256=6e97b9f0954807f30c2dd8e3165731ed6c477a1b365f194b69d81d7940a08332
# Best match: GitPython 3.0.3
# Processing GitPython-3.0.3-py3-none-any.whl
# Installing GitPython-3.0.3-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding GitPython 3.0.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/GitPython-3.0.3-py3.6.egg
# Searching for flake8-bugbear==19.8.0
# Reading https://pypi.org/simple/flake8-bugbear/
# Downloading https://files.pythonhosted.org/packages/9f/f8/170861859fb8ae97923b4fc28501dd25209925e25face836562d3e3f5ea2/flake8_bugbear-19.8.0-py35.py36.py37-none-any.whl#sha256=ded4d282778969b5ab5530ceba7aa1a9f1b86fa7618fc96a19a1d512331640f8
# Best match: flake8-bugbear 19.8.0
# Processing flake8_bugbear-19.8.0-py35.py36.py37-none-any.whl
# Installing flake8_bugbear-19.8.0-py35.py36.py37-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding flake8-bugbear 19.8.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/flake8_bugbear-19.8.0-py3.6.egg
# Searching for flake8==3.7.8
# Reading https://pypi.org/simple/flake8/
# Downloading https://files.pythonhosted.org/packages/26/de/3f815a99d86eb10464ea7bd6059c0172c7ca97d4bdcfca41051b388a653b/flake8-3.7.8-py2.py3-none-any.whl#sha256=8e9dfa3cecb2400b3738a42c54c3043e821682b9c840b0448c0503f781130696
# Best match: flake8 3.7.8
# Processing flake8-3.7.8-py2.py3-none-any.whl
# Installing flake8-3.7.8-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding flake8 3.7.8 to easy-install.pth file
# Installing flake8 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/flake8-3.7.8-py3.6.egg
# Searching for docformatter==1.3.0
# Reading https://pypi.org/simple/docformatter/
# Downloading https://files.pythonhosted.org/packages/35/52/41c0152a44873c8f11f0f9fe21b680588ae0e2b20e4a0a9b4812f8decbdc/docformatter-1.3.tar.gz#sha256=c68c8db0952d7ec6423581915fde3f23d4be5eccc11eb28a3415b5cd0a1e4f73
# Best match: docformatter 1.3
# Processing docformatter-1.3.tar.gz
# Writing /tmp/easy_install-k116e5id/docformatter-1.3/setup.cfg
# Running docformatter-1.3/setup.py -q bdist_egg --dist-dir /tmp/easy_install-k116e5id/docformatter-1.3/egg-dist-tmp-krzmycsk
# warning: no previously-included files found matching '.pre-commit-hooks.yaml'
# warning: no previously-included files found matching '.travis.yml'
# warning: no previously-included files found matching 'Makefile'
# zip_safe flag not set; analyzing archive contents...
# Moving docformatter-1.3-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding docformatter 1.3 to easy-install.pth file
# Installing docformatter script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/docformatter-1.3-py3.6.egg
# Searching for emoji==0.5.4
# Reading https://pypi.org/simple/emoji/
# Downloading https://files.pythonhosted.org/packages/40/8d/521be7f0091fe0f2ae690cc044faf43e3445e0ff33c574eae752dd7e39fa/emoji-0.5.4.tar.gz#sha256=60652d3a2dcee5b8af8acb097c31776fb6d808027aeb7221830f72cdafefc174
# Best match: emoji 0.5.4
# Processing emoji-0.5.4.tar.gz
# Writing /tmp/easy_install-iycdnrff/emoji-0.5.4/setup.cfg
# Running emoji-0.5.4/setup.py -q bdist_egg --dist-dir /tmp/easy_install-iycdnrff/emoji-0.5.4/egg-dist-tmp-6zgj7r5l
# Moving emoji-0.5.4-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding emoji 0.5.4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/emoji-0.5.4-py3.6.egg
# Searching for docutils==0.14
# Reading https://pypi.org/simple/docutils/
# Downloading https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl#sha256=02aec4bd92ab067f6ff27a38a38a41173bf01bed8f89157768c1573f53e474a6
# Best match: docutils 0.14
# Processing docutils-0.14-py3-none-any.whl
# Installing docutils-0.14-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding docutils 0.14 to easy-install.pth file
# Installing rst2pseudoxml.py script to /usr/local/bin
# Installing rst2latex.py script to /usr/local/bin
# Installing rst2man.py script to /usr/local/bin
# Installing rstpep2html.py script to /usr/local/bin
# Installing rst2html5.py script to /usr/local/bin
# Installing rst2html.py script to /usr/local/bin
# Installing rst2odt_prepstyles.py script to /usr/local/bin
# Installing rst2s5.py script to /usr/local/bin
# Installing rst2html4.py script to /usr/local/bin
# Installing rst2odt.py script to /usr/local/bin
# Installing rst2xetex.py script to /usr/local/bin
# Installing rst2xml.py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/docutils-0.14-py3.6.egg
# Searching for botocore==1.12.246
# Reading https://pypi.org/simple/botocore/
# Downloading https://files.pythonhosted.org/packages/6d/22/398af6ea8d5c6bac57154442068613df74e7adbf255417c6894ef49fda42/botocore-1.12.246-py2.py3-none-any.whl#sha256=6dcc121be4917cc731577a2ddff67b89cee6a4b0ec30241ce207a80a0d41990a
# Best match: botocore 1.12.246
# Processing botocore-1.12.246-py2.py3-none-any.whl
# Installing botocore-1.12.246-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding botocore 1.12.246 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/botocore-1.12.246-py3.6.egg
# Searching for boto3==1.9.246
# Reading https://pypi.org/simple/boto3/
# Downloading https://files.pythonhosted.org/packages/5b/cd/a888759c39670cac6b74027d3e3a93073ecb99135b1292d15bc2f3b6f90a/boto3-1.9.246-py2.py3-none-any.whl#sha256=9a84be232ff6432312c16b8e52cc5a01e6ff461cb9b50b3cafee24c6876a5012
# Best match: boto3 1.9.246
# Processing boto3-1.9.246-py2.py3-none-any.whl
# Installing boto3-1.9.246-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding boto3 1.9.246 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/boto3-1.9.246-py3.6.egg
# Searching for sphinxcontrib-serializinghtml
# Reading https://pypi.org/simple/sphinxcontrib-serializinghtml/
# Downloading https://files.pythonhosted.org/packages/57/b3/3648e48fa5682e61e9839d62de4e23af1795ceb738d68d73bd974257a95c/sphinxcontrib_serializinghtml-1.1.3-py2.py3-none-any.whl#sha256=db6615af393650bf1151a6cd39120c29abaf93cc60db8c48eb2dddbfdc3a9768
# Best match: sphinxcontrib-serializinghtml 1.1.3
# Processing sphinxcontrib_serializinghtml-1.1.3-py2.py3-none-any.whl
# Installing sphinxcontrib_serializinghtml-1.1.3-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-serializinghtml 1.1.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_serializinghtml-1.1.3-py3.6.egg
# Searching for sphinxcontrib-qthelp
# Reading https://pypi.org/simple/sphinxcontrib-qthelp/
# Downloading https://files.pythonhosted.org/packages/ce/5b/4747c3ba98b3a3e21a66faa183d8f79b9ded70e74212a7988d236a6eb78a/sphinxcontrib_qthelp-1.0.2-py2.py3-none-any.whl#sha256=513049b93031beb1f57d4daea74068a4feb77aa5630f856fcff2e50de14e9a20
# Best match: sphinxcontrib-qthelp 1.0.2
# Processing sphinxcontrib_qthelp-1.0.2-py2.py3-none-any.whl
# Installing sphinxcontrib_qthelp-1.0.2-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-qthelp 1.0.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_qthelp-1.0.2-py3.6.egg
# Searching for sphinxcontrib-jsmath
# Reading https://pypi.org/simple/sphinxcontrib-jsmath/
# Downloading https://files.pythonhosted.org/packages/c2/42/4c8646762ee83602e3fb3fbe774c2fac12f317deb0b5dbeeedd2d3ba4b77/sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl#sha256=2ec2eaebfb78f3f2078e73666b1415417a116cc848b72e5172e596c871103178
# Best match: sphinxcontrib-jsmath 1.0.1
# Processing sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl
# Installing sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-jsmath 1.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_jsmath-1.0.1-py3.6.egg
# Searching for sphinxcontrib-htmlhelp
# Reading https://pypi.org/simple/sphinxcontrib-htmlhelp/
# Downloading https://files.pythonhosted.org/packages/e4/35/80a67cc493f4a8a9634ab203a77aaa1b84d79ccb1c02eca72cb084d2c7f7/sphinxcontrib_htmlhelp-1.0.2-py2.py3-none-any.whl#sha256=d4fd39a65a625c9df86d7fa8a2d9f3cd8299a3a4b15db63b50aac9e161d8eff7
# Best match: sphinxcontrib-htmlhelp 1.0.2
# Processing sphinxcontrib_htmlhelp-1.0.2-py2.py3-none-any.whl
# Installing sphinxcontrib_htmlhelp-1.0.2-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-htmlhelp 1.0.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_htmlhelp-1.0.2-py3.6.egg
# Searching for sphinxcontrib-devhelp
# Reading https://pypi.org/simple/sphinxcontrib-devhelp/
# Downloading https://files.pythonhosted.org/packages/b0/a3/fea98741f0b2f2902fbf6c35c8e91b22cd0dd13387291e81d457f9a93066/sphinxcontrib_devhelp-1.0.1-py2.py3-none-any.whl#sha256=9512ecb00a2b0821a146736b39f7aeb90759834b07e81e8cc23a9c70bacb9981
# Best match: sphinxcontrib-devhelp 1.0.1
# Processing sphinxcontrib_devhelp-1.0.1-py2.py3-none-any.whl
# Installing sphinxcontrib_devhelp-1.0.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-devhelp 1.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_devhelp-1.0.1-py3.6.egg
# Searching for sphinxcontrib-applehelp
# Reading https://pypi.org/simple/sphinxcontrib-applehelp/
# Downloading https://files.pythonhosted.org/packages/13/9a/4428b3114d654cb1cd34d90d5e6fab938d5436f94a571155187ea1dd78b4/sphinxcontrib_applehelp-1.0.1-py2.py3-none-any.whl#sha256=fb8dee85af95e5c30c91f10e7eb3c8967308518e0f7488a2828ef7bc191d0d5d
# Best match: sphinxcontrib-applehelp 1.0.1
# Processing sphinxcontrib_applehelp-1.0.1-py2.py3-none-any.whl
# Installing sphinxcontrib_applehelp-1.0.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding sphinxcontrib-applehelp 1.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/sphinxcontrib_applehelp-1.0.1-py3.6.egg
# Searching for commonmark>=0.8.1
# Reading https://pypi.org/simple/commonmark/
# Downloading https://files.pythonhosted.org/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl#sha256=da2f38c92590f83de410ba1a3cbceafbc74fee9def35f9251ba9a971d6d66fd9
# Best match: commonmark 0.9.1
# Processing commonmark-0.9.1-py2.py3-none-any.whl
# Installing commonmark-0.9.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding commonmark 0.9.1 to easy-install.pth file
# Installing cmark script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/commonmark-0.9.1-py3.6.egg
# Searching for markdown<3.0
# Reading https://pypi.org/simple/markdown/
# Downloading https://files.pythonhosted.org/packages/6d/7d/488b90f470b96531a3f5788cf12a93332f543dbab13c423a5e7ce96a0493/Markdown-2.6.11-py2.py3-none-any.whl#sha256=9ba587db9daee7ec761cfc656272be6aabe2ed300fece21208e4aab2e457bc8f
# Best match: Markdown 2.6.11
# Processing Markdown-2.6.11-py2.py3-none-any.whl
# Installing Markdown-2.6.11-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding Markdown 2.6.11 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/Markdown-2.6.11-py3.6.egg
# Searching for pluggy<1.0,>=0.12
# Reading https://pypi.org/simple/pluggy/
# Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl#sha256=966c145cd83c96502c3c3868f50408687b38434af77734af1e9ca461a4081d2d
# Best match: pluggy 0.13.1
# Processing pluggy-0.13.1-py2.py3-none-any.whl
# Installing pluggy-0.13.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pluggy 0.13.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pluggy-0.13.1-py3.6.egg
# Searching for gitdb2>=2.0.0
# Reading https://pypi.org/simple/gitdb2/
# Downloading https://files.pythonhosted.org/packages/03/6c/99296f89bad2ef85626e1df9f677acbee8885bb043ad82ad3ed4746d2325/gitdb2-2.0.6-py2.py3-none-any.whl#sha256=96bbb507d765a7f51eb802554a9cfe194a174582f772e0d89f4e87288c288b7b
# Best match: gitdb2 2.0.6
# Processing gitdb2-2.0.6-py2.py3-none-any.whl
# Installing gitdb2-2.0.6-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding gitdb2 2.0.6 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/gitdb2-2.0.6-py3.6.egg
# Searching for pyflakes<2.2.0,>=2.1.0
# Reading https://pypi.org/simple/pyflakes/
# Downloading https://files.pythonhosted.org/packages/84/f2/ed0ffb887f8138a8fe5a621b8c0bb9598bfb3989e029f6c6a85ee66628ee/pyflakes-2.1.1-py2.py3-none-any.whl#sha256=17dbeb2e3f4d772725c777fabc446d5634d1038f234e77343108ce445ea69ce0
# Best match: pyflakes 2.1.1
# Processing pyflakes-2.1.1-py2.py3-none-any.whl
# Installing pyflakes-2.1.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pyflakes 2.1.1 to easy-install.pth file
# Installing pyflakes script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pyflakes-2.1.1-py3.6.egg
# Searching for pycodestyle<2.6.0,>=2.5.0
# Reading https://pypi.org/simple/pycodestyle/
# Downloading https://files.pythonhosted.org/packages/0e/0c/04a353e104d2f324f8ee5f4b32012618c1c86dd79e52a433b64fceed511b/pycodestyle-2.5.0-py2.py3-none-any.whl#sha256=95a2219d12372f05704562a14ec30bc76b05a5b297b21a5dfe3f6fac3491ae56
# Best match: pycodestyle 2.5.0
# Processing pycodestyle-2.5.0-py2.py3-none-any.whl
# Installing pycodestyle-2.5.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pycodestyle 2.5.0 to easy-install.pth file
# Installing pycodestyle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pycodestyle-2.5.0-py3.6.egg
# Searching for mccabe<0.7.0,>=0.6.0
# Reading https://pypi.org/simple/mccabe/
# Downloading https://files.pythonhosted.org/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl#sha256=ab8a6258860da4b6677da4bd2fe5dc2c659cff31b3ee4f7f5d64e79735b80d42
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py2.py3-none-any.whl
# Installing mccabe-0.6.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding mccabe 0.6.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/mccabe-0.6.1-py3.6.egg
# Searching for untokenize
# Reading https://pypi.org/simple/untokenize/
# Downloading https://files.pythonhosted.org/packages/f7/46/e7cea8159199096e1df52da20a57a6665da80c37fb8aeb848a3e47442c32/untokenize-0.1.1.tar.gz#sha256=3865dbbbb8efb4bb5eaa72f1be7f3e0be00ea8b7f125c69cbd1f5fda926f37a2
# Best match: untokenize 0.1.1
# Processing untokenize-0.1.1.tar.gz
# Writing /tmp/easy_install-6aqg0gou/untokenize-0.1.1/setup.cfg
# Running untokenize-0.1.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-6aqg0gou/untokenize-0.1.1/egg-dist-tmp-ya9w2k26
# warning: no previously-included files found matching '.travis.yml'
# warning: no previously-included files found matching 'Makefile'
# warning: no previously-included files found matching 'test_acid.py'
# zip_safe flag not set; analyzing archive contents...
# Moving untokenize-0.1.1-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding untokenize 0.1.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/untokenize-0.1.1-py3.6.egg
# Searching for s3transfer<0.3.0,>=0.2.0
# Reading https://pypi.org/simple/s3transfer/
# Downloading https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl#sha256=b780f2411b824cb541dbcd2c713d0cb61c7d1bcadae204cdddda2b35cef493ba
# Best match: s3transfer 0.2.1
# Processing s3transfer-0.2.1-py2.py3-none-any.whl
# Installing s3transfer-0.2.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding s3transfer 0.2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/s3transfer-0.2.1-py3.6.egg
# Searching for smmap2>=2.0.0
# Reading https://pypi.org/simple/smmap2/
# Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl#sha256=0555a7bf4df71d1ef4218e4807bbf9b201f910174e6e08af2e138d4e517b4dde
# Best match: smmap2 2.0.5
# Processing smmap2-2.0.5-py2.py3-none-any.whl
# Installing smmap2-2.0.5-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding smmap2 2.0.5 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/smmap2-2.0.5-py3.6.egg
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scikit-learn==0.22.1
# Best match: scikit-learn 0.22.1
# Adding scikit-learn 0.22.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pillow==6.2.2
# Best match: Pillow 6.2.2
# Adding Pillow 6.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.17.5
# Best match: numpy 1.17.5
# Adding numpy 1.17.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for joblib==0.14.1
# Best match: joblib 0.14.1
# Adding joblib 0.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for snowballstemmer==2.0.0
# Best match: snowballstemmer 2.0.0
# Adding snowballstemmer 2.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==45.1.0
# Best match: setuptools 45.1.0
# Adding setuptools 45.1.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for packaging==20.1
# Best match: packaging 20.1
# Adding packaging 20.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for imagesize==1.2.0
# Best match: imagesize 1.2.0
# Adding imagesize 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Babel==2.8.0
# Best match: Babel 2.8.0
# Adding Babel 2.8.0 to easy-install.pth file
# Installing pybabel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for alabaster==0.7.12
# Best match: alabaster 0.7.12
# Adding alabaster 0.7.12 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pygments==2.1.3
# Best match: Pygments 2.1.3
# Adding Pygments 2.1.3 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.11.1
# Best match: Jinja2 2.11.1
# Adding Jinja2 2.11.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.8
# Best match: idna 2.8
# Adding idna 2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2019.11.28
# Best match: certifi 2019.11.28
# Adding certifi 2019.11.28 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ptyprocess==0.6.0
# Best match: ptyprocess 0.6.0
# Adding ptyprocess 0.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wcwidth==0.1.8
# Best match: wcwidth 0.1.8
# Adding wcwidth 0.1.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for py==1.8.1
# Best match: py 1.8.1
# Adding py 1.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for more-itertools==8.2.0
# Best match: more-itertools 8.2.0
# Adding more-itertools 8.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for importlib-metadata==1.5.0
# Best match: importlib-metadata 1.5.0
# Adding importlib-metadata 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for attrs==19.3.0
# Best match: attrs 19.3.0
# Adding attrs 19.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for entrypoints==0.3
# Best match: entrypoints 0.3
# Adding entrypoints 0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.6.1
# Best match: python-dateutil 2.6.1
# Adding python-dateutil 2.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jmespath==0.9.4
# Best match: jmespath 0.9.4
# Adding jmespath 0.9.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyparsing==2.4.6
# Best match: pyparsing 2.4.6
# Adding pyparsing 2.4.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for MarkupSafe==1.1.1
# Best match: MarkupSafe 1.1.1
# Adding MarkupSafe 1.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for zipp==2.1.0
# Best match: zipp 2.1.0
# Adding zipp 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for parlai==0.1.0
# running install
# running bdist_egg
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/parlai
# copying parlai/__init__.py -> build/lib/parlai
# creating build/lib/example_parlai_internal
# copying example_parlai_internal/__init__.py -> build/lib/example_parlai_internal
# creating build/lib/projects
# copying projects/__init__.py -> build/lib/projects
# creating build/lib/parlai/zoo
# copying parlai/zoo/__init__.py -> build/lib/parlai/zoo
# copying parlai/zoo/model_list.py -> build/lib/parlai/zoo
# creating build/lib/parlai/scripts
# copying parlai/scripts/self_chat.py -> build/lib/parlai/scripts
# copying parlai/scripts/detect_offensive_language.py -> build/lib/parlai/scripts
# copying parlai/scripts/__init__.py -> build/lib/parlai/scripts
# copying parlai/scripts/build_candidates.py -> build/lib/parlai/scripts
# copying parlai/scripts/eval_model.py -> build/lib/parlai/scripts
# copying parlai/scripts/profile_train.py -> build/lib/parlai/scripts
# copying parlai/scripts/eval_ppl.py -> build/lib/parlai/scripts
# copying parlai/scripts/build_dict.py -> build/lib/parlai/scripts
# copying parlai/scripts/profile_interactive.py -> build/lib/parlai/scripts
# copying parlai/scripts/display_model.py -> build/lib/parlai/scripts
# copying parlai/scripts/display_data.py -> build/lib/parlai/scripts
# copying parlai/scripts/eval_wordstat.py -> build/lib/parlai/scripts
# copying parlai/scripts/distributed_train.py -> build/lib/parlai/scripts
# copying parlai/scripts/interactive.py -> build/lib/parlai/scripts
# copying parlai/scripts/multiprocessing_train.py -> build/lib/parlai/scripts
# copying parlai/scripts/train_model.py -> build/lib/parlai/scripts
# copying parlai/scripts/data_stats.py -> build/lib/parlai/scripts
# copying parlai/scripts/verify_data.py -> build/lib/parlai/scripts
# copying parlai/scripts/interactive_web.py -> build/lib/parlai/scripts
# copying parlai/scripts/extract_image_feature.py -> build/lib/parlai/scripts
# copying parlai/scripts/convert_data_to_parlai_format.py -> build/lib/parlai/scripts
# copying parlai/scripts/convert_data_to_fasttext_format.py -> build/lib/parlai/scripts
# copying parlai/scripts/convo_render.py -> build/lib/parlai/scripts
# creating build/lib/parlai/nn
# copying parlai/nn/__init__.py -> build/lib/parlai/nn
# copying parlai/nn/lr_scheduler.py -> build/lib/parlai/nn
# creating build/lib/parlai/core
# copying parlai/core/metrics.py -> build/lib/parlai/core
# copying parlai/core/torch_classifier_agent.py -> build/lib/parlai/core
# copying parlai/core/teachers.py -> build/lib/parlai/core
# copying parlai/core/worlds.py -> build/lib/parlai/core
# copying parlai/core/__init__.py -> build/lib/parlai/core
# copying parlai/core/message.py -> build/lib/parlai/core
# copying parlai/core/torch_ranker_agent.py -> build/lib/parlai/core
# copying parlai/core/exceptions.py -> build/lib/parlai/core
# copying parlai/core/agents.py -> build/lib/parlai/core
# copying parlai/core/dict.py -> build/lib/parlai/core
# copying parlai/core/loader.py -> build/lib/parlai/core
# copying parlai/core/opt.py -> build/lib/parlai/core
# copying parlai/core/logs.py -> build/lib/parlai/core
# copying parlai/core/gpt2_helper.py -> build/lib/parlai/core
# copying parlai/core/image_featurizers.py -> build/lib/parlai/core
# copying parlai/core/params.py -> build/lib/parlai/core
# copying parlai/core/torch_generator_agent.py -> build/lib/parlai/core
# copying parlai/core/torch_agent.py -> build/lib/parlai/core
# copying parlai/core/build_data.py -> build/lib/parlai/core
# creating build/lib/parlai/mturk
# copying parlai/mturk/__init__.py -> build/lib/parlai/mturk
# creating build/lib/parlai/agents
# copying parlai/agents/__init__.py -> build/lib/parlai/agents
# creating build/lib/parlai/chat_service
# copying parlai/chat_service/__init__.py -> build/lib/parlai/chat_service
# creating build/lib/parlai/tasks
# copying parlai/tasks/task_list.py -> build/lib/parlai/tasks
# copying parlai/tasks/tasks.py -> build/lib/parlai/tasks
# copying parlai/tasks/__init__.py -> build/lib/parlai/tasks
# creating build/lib/parlai/utils
# copying parlai/utils/thread.py -> build/lib/parlai/utils
# copying parlai/utils/torch.py -> build/lib/parlai/utils
# copying parlai/utils/__init__.py -> build/lib/parlai/utils
# copying parlai/utils/flake8.py -> build/lib/parlai/utils
# copying parlai/utils/pickle.py -> build/lib/parlai/utils
# copying parlai/utils/misc.py -> build/lib/parlai/utils
# copying parlai/utils/typing.py -> build/lib/parlai/utils
# copying parlai/utils/testing.py -> build/lib/parlai/utils
# copying parlai/utils/strings.py -> build/lib/parlai/utils
# copying parlai/utils/world_logging.py -> build/lib/parlai/utils
# copying parlai/utils/distributed.py -> build/lib/parlai/utils
# copying parlai/utils/logging.py -> build/lib/parlai/utils
# copying parlai/utils/safety.py -> build/lib/parlai/utils
# creating build/lib/parlai/zoo/glove_vectors
# copying parlai/zoo/glove_vectors/build.py -> build/lib/parlai/zoo/glove_vectors
# copying parlai/zoo/glove_vectors/__init__.py -> build/lib/parlai/zoo/glove_vectors
# creating build/lib/parlai/zoo/fasttext_vectors
# copying parlai/zoo/fasttext_vectors/build.py -> build/lib/parlai/zoo/fasttext_vectors
# copying parlai/zoo/fasttext_vectors/__init__.py -> build/lib/parlai/zoo/fasttext_vectors
# creating build/lib/parlai/zoo/wikipedia_20161221
# copying parlai/zoo/wikipedia_20161221/__init__.py -> build/lib/parlai/zoo/wikipedia_20161221
# copying parlai/zoo/wikipedia_20161221/tfidf_retriever.py -> build/lib/parlai/zoo/wikipedia_20161221
# creating build/lib/parlai/zoo/wikipedia_full
# copying parlai/zoo/wikipedia_full/__init__.py -> build/lib/parlai/zoo/wikipedia_full
# copying parlai/zoo/wikipedia_full/tfidf_retriever.py -> build/lib/parlai/zoo/wikipedia_full
# creating build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/build.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/poly_model_huge_wikito.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/__init__.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/bi_model_huge_wikito.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/bi_model_huge_reddit.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/cross_model_huge_wikito.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/model_bi.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/cross_model_huge_reddit.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/model_poly.py -> build/lib/parlai/zoo/pretrained_transformers
# copying parlai/zoo/pretrained_transformers/poly_model_huge_reddit.py -> build/lib/parlai/zoo/pretrained_transformers
# creating build/lib/parlai/zoo/fasttext_cc_vectors
# copying parlai/zoo/fasttext_cc_vectors/build.py -> build/lib/parlai/zoo/fasttext_cc_vectors
# copying parlai/zoo/fasttext_cc_vectors/__init__.py -> build/lib/parlai/zoo/fasttext_cc_vectors
# creating build/lib/parlai/zoo/wizard_of_wikipedia
# copying parlai/zoo/wizard_of_wikipedia/__init__.py -> build/lib/parlai/zoo/wizard_of_wikipedia
# copying parlai/zoo/wizard_of_wikipedia/knowledge_retriever.py -> build/lib/parlai/zoo/wizard_of_wikipedia
# copying parlai/zoo/wizard_of_wikipedia/full_dialogue_retrieval_model.py -> build/lib/parlai/zoo/wizard_of_wikipedia
# copying parlai/zoo/wizard_of_wikipedia/end2end_generator.py -> build/lib/parlai/zoo/wizard_of_wikipedia
# creating build/lib/parlai/zoo/bert
# copying parlai/zoo/bert/build.py -> build/lib/parlai/zoo/bert
# copying parlai/zoo/bert/__init__.py -> build/lib/parlai/zoo/bert
# creating build/lib/parlai/zoo/convai2
# copying parlai/zoo/convai2/__init__.py -> build/lib/parlai/zoo/convai2
# copying parlai/zoo/convai2/kvmemnn.py -> build/lib/parlai/zoo/convai2
# copying parlai/zoo/convai2/seq2seq.py -> build/lib/parlai/zoo/convai2
# copying parlai/zoo/convai2/language_model.py -> build/lib/parlai/zoo/convai2
# creating build/lib/parlai/zoo/controllable_dialogue
# copying parlai/zoo/controllable_dialogue/build.py -> build/lib/parlai/zoo/controllable_dialogue
# copying parlai/zoo/controllable_dialogue/__init__.py -> build/lib/parlai/zoo/controllable_dialogue
# creating build/lib/parlai/zoo/unittest
# copying parlai/zoo/unittest/build.py -> build/lib/parlai/zoo/unittest
# copying parlai/zoo/unittest/__init__.py -> build/lib/parlai/zoo/unittest
# creating build/lib/parlai/zoo/image_chat
# copying parlai/zoo/image_chat/__init__.py -> build/lib/parlai/zoo/image_chat
# copying parlai/zoo/image_chat/transresnet_multimodal.py -> build/lib/parlai/zoo/image_chat
# creating build/lib/parlai/zoo/drqa
# copying parlai/zoo/drqa/__init__.py -> build/lib/parlai/zoo/drqa
# copying parlai/zoo/drqa/squad.py -> build/lib/parlai/zoo/drqa
# creating build/lib/parlai/zoo/personality_captions
# copying parlai/zoo/personality_captions/transresnet.py -> build/lib/parlai/zoo/personality_captions
# copying parlai/zoo/personality_captions/__init__.py -> build/lib/parlai/zoo/personality_captions
# creating build/lib/parlai/zoo/dialogue_safety
# copying parlai/zoo/dialogue_safety/__init__.py -> build/lib/parlai/zoo/dialogue_safety
# copying parlai/zoo/dialogue_safety/single_turn.py -> build/lib/parlai/zoo/dialogue_safety
# copying parlai/zoo/dialogue_safety/multi_turn.py -> build/lib/parlai/zoo/dialogue_safety
# creating build/lib/parlai/zoo/light
# copying parlai/zoo/light/__init__.py -> build/lib/parlai/zoo/light
# copying parlai/zoo/light/biranker_dialogue.py -> build/lib/parlai/zoo/light
# creating build/lib/parlai/zoo/self_feeding
# copying parlai/zoo/self_feeding/__init__.py -> build/lib/parlai/zoo/self_feeding
# copying parlai/zoo/self_feeding/hh131k_hb60k_fb60k_st1k.py -> build/lib/parlai/zoo/self_feeding
# creating build/lib/parlai/mturk/scripts
# copying parlai/mturk/scripts/bonus_workers.py -> build/lib/parlai/mturk/scripts
# copying parlai/mturk/scripts/auto_complete_hit.py -> build/lib/parlai/mturk/scripts
# copying parlai/mturk/scripts/__init__.py -> build/lib/parlai/mturk/scripts
# copying parlai/mturk/scripts/delete_hits.py -> build/lib/parlai/mturk/scripts
# creating build/lib/parlai/mturk/core
# copying parlai/mturk/core/mturk_manager.py -> build/lib/parlai/mturk/core
# copying parlai/mturk/core/worlds.py -> build/lib/parlai/mturk/core
# ...
# Processing sphinx_autodoc_typehints-1.10.3-py3.6.egg
# sphinx-autodoc-typehints 1.10.3 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinx_autodoc_typehints-1.10.3-py3.6.egg
# Searching for sphinx-rtd-theme==0.4.3
# Best match: sphinx-rtd-theme 0.4.3
# Processing sphinx_rtd_theme-0.4.3-py3.6.egg
# sphinx-rtd-theme 0.4.3 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinx_rtd_theme-0.4.3-py3.6.egg
# Searching for Sphinx==2.2.0
# Best match: Sphinx 2.2.0
# Processing Sphinx-2.2.0-py3.6.egg
# Sphinx 2.2.0 is already the active version in easy-install.pth
# Installing sphinx-apidoc script to /usr/local/bin
# Installing sphinx-autogen script to /usr/local/bin
# Installing sphinx-build script to /usr/local/bin
# Installing sphinx-quickstart script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/Sphinx-2.2.0-py3.6.egg
# Searching for sh==1.12.14
# Best match: sh 1.12.14
# Processing sh-1.12.14-py3.6.egg
# sh 1.12.14 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sh-1.12.14-py3.6.egg
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scikit-learn==0.22.1
# Best match: scikit-learn 0.22.1
# Adding scikit-learn 0.22.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests-mock==1.7.0
# Best match: requests-mock 1.7.0
# Processing requests_mock-1.7.0-py3.6.egg
# requests-mock 1.7.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/requests_mock-1.7.0-py3.6.egg
# Searching for requests==2.22.0
# Best match: requests 2.22.0
# Processing requests-2.22.0-py3.6.egg
# requests 2.22.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/requests-2.22.0-py3.6.egg
# Searching for recommonmark==0.6.0
# Best match: recommonmark 0.6.0
# Processing recommonmark-0.6.0-py3.6.egg
# recommonmark 0.6.0 is already the active version in easy-install.pth
# Installing cm2html script to /usr/local/bin
# Installing cm2latex script to /usr/local/bin
# Installing cm2man script to /usr/local/bin
# Installing cm2pseudoxml script to /usr/local/bin
# Installing cm2xetex script to /usr/local/bin
# Installing cm2xml script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/recommonmark-0.6.0-py3.6.egg
# Searching for regex==2019.8.19
# Best match: regex 2019.8.19
# Processing regex-2019.8.19-py3.6-linux-x86_64.egg
# regex 2019.8.19 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/regex-2019.8.19-py3.6-linux-x86_64.egg
# Searching for pyzmq==18.1.0
# Best match: pyzmq 18.1.0
# Processing pyzmq-18.1.0-py3.6-linux-x86_64.egg
# pyzmq 18.1.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/pyzmq-18.1.0-py3.6-linux-x86_64.egg
# Searching for py-rouge==1.1
# Best match: py-rouge 1.1
# Processing py_rouge-1.1-py3.6.egg
# py-rouge 1.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/py_rouge-1.1-py3.6.egg
# Searching for py-gfm==0.1.4
# Best match: py-gfm 0.1.4
# Processing py_gfm-0.1.4-py3.6.egg
# py-gfm 0.1.4 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/py_gfm-0.1.4-py3.6.egg
# Searching for Pillow==6.2.2
# Best match: Pillow 6.2.2
# Adding Pillow 6.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pexpect==4.7.0
# Best match: pexpect 4.7.0
# Processing pexpect-4.7.0-py3.6.egg
# pexpect 4.7.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/pexpect-4.7.0-py3.6.egg
# Searching for pytest==5.3.2
# Best match: pytest 5.3.2
# Processing pytest-5.3.2-py3.6.egg
# pytest 5.3.2 is already the active version in easy-install.pth
# Installing py.test script to /usr/local/bin
# Installing pytest script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/pytest-5.3.2-py3.6.egg
# Searching for numpy==1.17.5
# Best match: numpy 1.17.5
# Adding numpy 1.17.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for nltk==3.4.5
# Best match: nltk 3.4.5
# Processing nltk-3.4.5-py3.6.egg
# nltk 3.4.5 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/nltk-3.4.5-py3.6.egg
# Searching for joblib==0.14.1
# Best match: joblib 0.14.1
# Adding joblib 0.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for h5py==2.10.0
# Best match: h5py 2.10.0
# Processing h5py-2.10.0-py3.6-linux-x86_64.egg
# h5py 2.10.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/h5py-2.10.0-py3.6-linux-x86_64.egg
# Searching for GitPython==3.0.3
# Best match: GitPython 3.0.3
# Processing GitPython-3.0.3-py3.6.egg
# GitPython 3.0.3 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/GitPython-3.0.3-py3.6.egg
# Searching for flake8-bugbear==19.8.0
# Best match: flake8-bugbear 19.8.0
# Processing flake8_bugbear-19.8.0-py3.6.egg
# flake8-bugbear 19.8.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/flake8_bugbear-19.8.0-py3.6.egg
# Searching for flake8==3.7.8
# Best match: flake8 3.7.8
# Processing flake8-3.7.8-py3.6.egg
# flake8 3.7.8 is already the active version in easy-install.pth
# Installing flake8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/flake8-3.7.8-py3.6.egg
# Searching for docformatter==1.3
# Best match: docformatter 1.3
# Processing docformatter-1.3-py3.6.egg
# docformatter 1.3 is already the active version in easy-install.pth
# Installing docformatter script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/docformatter-1.3-py3.6.egg
# Searching for emoji==0.5.4
# Best match: emoji 0.5.4
# Processing emoji-0.5.4-py3.6.egg
# emoji 0.5.4 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/emoji-0.5.4-py3.6.egg
# Searching for docutils==0.14
# Best match: docutils 0.14
# Processing docutils-0.14-py3.6.egg
# docutils 0.14 is already the active version in easy-install.pth
# Installing rst2pseudoxml.py script to /usr/local/bin
# Installing rst2latex.py script to /usr/local/bin
# Installing rst2man.py script to /usr/local/bin
# Installing rstpep2html.py script to /usr/local/bin
# Installing rst2html5.py script to /usr/local/bin
# Installing rst2html.py script to /usr/local/bin
# Installing rst2odt_prepstyles.py script to /usr/local/bin
# Installing rst2s5.py script to /usr/local/bin
# Installing rst2html4.py script to /usr/local/bin
# Installing rst2odt.py script to /usr/local/bin
# Installing rst2xetex.py script to /usr/local/bin
# Installing rst2xml.py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/docutils-0.14-py3.6.egg
# Searching for botocore==1.12.246
# Best match: botocore 1.12.246
# Processing botocore-1.12.246-py3.6.egg
# botocore 1.12.246 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/botocore-1.12.246-py3.6.egg
# Searching for boto3==1.9.246
# Best match: boto3 1.9.246
# Processing boto3-1.9.246-py3.6.egg
# boto3 1.9.246 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/boto3-1.9.246-py3.6.egg
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for sphinxcontrib-serializinghtml==1.1.3
# Best match: sphinxcontrib-serializinghtml 1.1.3
# Processing sphinxcontrib_serializinghtml-1.1.3-py3.6.egg
# sphinxcontrib-serializinghtml 1.1.3 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_serializinghtml-1.1.3-py3.6.egg
# Searching for sphinxcontrib-qthelp==1.0.2
# Best match: sphinxcontrib-qthelp 1.0.2
# Processing sphinxcontrib_qthelp-1.0.2-py3.6.egg
# sphinxcontrib-qthelp 1.0.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_qthelp-1.0.2-py3.6.egg
# Searching for sphinxcontrib-jsmath==1.0.1
# Best match: sphinxcontrib-jsmath 1.0.1
# Processing sphinxcontrib_jsmath-1.0.1-py3.6.egg
# sphinxcontrib-jsmath 1.0.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_jsmath-1.0.1-py3.6.egg
# Searching for sphinxcontrib-htmlhelp==1.0.2
# Best match: sphinxcontrib-htmlhelp 1.0.2
# Processing sphinxcontrib_htmlhelp-1.0.2-py3.6.egg
# sphinxcontrib-htmlhelp 1.0.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_htmlhelp-1.0.2-py3.6.egg
# Searching for sphinxcontrib-devhelp==1.0.1
# Best match: sphinxcontrib-devhelp 1.0.1
# Processing sphinxcontrib_devhelp-1.0.1-py3.6.egg
# sphinxcontrib-devhelp 1.0.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_devhelp-1.0.1-py3.6.egg
# Searching for sphinxcontrib-applehelp==1.0.1
# Best match: sphinxcontrib-applehelp 1.0.1
# Processing sphinxcontrib_applehelp-1.0.1-py3.6.egg
# sphinxcontrib-applehelp 1.0.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/sphinxcontrib_applehelp-1.0.1-py3.6.egg
# Searching for snowballstemmer==2.0.0
# Best match: snowballstemmer 2.0.0
# Adding snowballstemmer 2.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==45.1.0
# Best match: setuptools 45.1.0
# Adding setuptools 45.1.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for packaging==20.1
# Best match: packaging 20.1
# Adding packaging 20.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for imagesize==1.2.0
# Best match: imagesize 1.2.0
# Adding imagesize 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Babel==2.8.0
# Best match: Babel 2.8.0
# Adding Babel 2.8.0 to easy-install.pth file
# Installing pybabel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for alabaster==0.7.12
# Best match: alabaster 0.7.12
# Adding alabaster 0.7.12 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pygments==2.1.3
# Best match: Pygments 2.1.3
# Adding Pygments 2.1.3 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.11.1
# Best match: Jinja2 2.11.1
# Adding Jinja2 2.11.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.8
# Best match: idna 2.8
# Adding idna 2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2019.11.28
# Best match: certifi 2019.11.28
# Adding certifi 2019.11.28 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for commonmark==0.9.1
# Best match: commonmark 0.9.1
# Processing commonmark-0.9.1-py3.6.egg
# commonmark 0.9.1 is already the active version in easy-install.pth
# Installing cmark script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/commonmark-0.9.1-py3.6.egg
# Searching for Markdown==2.6.11
# Best match: Markdown 2.6.11
# Processing Markdown-2.6.11-py3.6.egg
# Markdown 2.6.11 is already the active version in easy-install.pth
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/Markdown-2.6.11-py3.6.egg
# Searching for ptyprocess==0.6.0
# Best match: ptyprocess 0.6.0
# Adding ptyprocess 0.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wcwidth==0.1.8
# Best match: wcwidth 0.1.8
# Adding wcwidth 0.1.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for py==1.8.1
# Best match: py 1.8.1
# Adding py 1.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pluggy==0.13.1
# Best match: pluggy 0.13.1
# Processing pluggy-0.13.1-py3.6.egg
# pluggy 0.13.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/pluggy-0.13.1-py3.6.egg
# Searching for more-itertools==8.2.0
# Best match: more-itertools 8.2.0
# Adding more-itertools 8.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for importlib-metadata==1.5.0
# Best match: importlib-metadata 1.5.0
# Adding importlib-metadata 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for attrs==19.3.0
# Best match: attrs 19.3.0
# Adding attrs 19.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gitdb2==2.0.6
# Best match: gitdb2 2.0.6
# Processing gitdb2-2.0.6-py3.6.egg
# gitdb2 2.0.6 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/gitdb2-2.0.6-py3.6.egg
# Searching for pyflakes==2.1.1
# Best match: pyflakes 2.1.1
# Processing pyflakes-2.1.1-py3.6.egg
# pyflakes 2.1.1 is already the active version in easy-install.pth
# Installing pyflakes script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/pyflakes-2.1.1-py3.6.egg
# Searching for pycodestyle==2.5.0
# Best match: pycodestyle 2.5.0
# Processing pycodestyle-2.5.0-py3.6.egg
# pycodestyle 2.5.0 is already the active version in easy-install.pth
# Installing pycodestyle script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/pycodestyle-2.5.0-py3.6.egg
# Searching for mccabe==0.6.1
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py3.6.egg
# mccabe 0.6.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/mccabe-0.6.1-py3.6.egg
# Searching for entrypoints==0.3
# Best match: entrypoints 0.3
# Adding entrypoints 0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for untokenize==0.1.1
# Best match: untokenize 0.1.1
# Processing untokenize-0.1.1-py3.6.egg
# untokenize 0.1.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/untokenize-0.1.1-py3.6.egg
# Searching for python-dateutil==2.6.1
# Best match: python-dateutil 2.6.1
# Adding python-dateutil 2.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jmespath==0.9.4
# Best match: jmespath 0.9.4
# Adding jmespath 0.9.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for s3transfer==0.2.1
# Best match: s3transfer 0.2.1
# Processing s3transfer-0.2.1-py3.6.egg
# s3transfer 0.2.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/s3transfer-0.2.1-py3.6.egg
# Searching for pyparsing==2.4.6
# Best match: pyparsing 2.4.6
# Adding pyparsing 2.4.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for MarkupSafe==1.1.1
# Best match: MarkupSafe 1.1.1
# Adding MarkupSafe 1.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for zipp==2.1.0
# Best match: zipp 2.1.0
# Adding zipp 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for smmap2==2.0.5
# Best match: smmap2 2.0.5
# Processing smmap2-2.0.5-py3.6.egg
# smmap2 2.0.5 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/smmap2-2.0.5-py3.6.egg
# Finished processing dependencies for parlai==0.1.0

# %%
# !pip install 'git+https://github.com/rsennrich/subword-nmt.git#egg=subword-nmt'
# Out:
# Collecting subword-nmt
#   Cloning https://github.com/rsennrich/subword-nmt.git to /tmp/pip-install-mtfwy8h5/subword-nmt
#   Running command git clone -q https://github.com/rsennrich/subword-nmt.git /tmp/pip-install-mtfwy8h5/subword-nmt
# Building wheels for collected packages: subword-nmt
#   Building wheel for subword-nmt (setup.py) ... done
#   Created wheel for subword-nmt: filename=subword_nmt-0.3.7-cp36-none-any.whl size=128115 sha256=2e355028b3d7e577e0ce9d1e3bbcb1bf9bc7a891e0f32b7687c764e867c82da6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dzk21s_w/wheels/05/2b/3a/73cd213b79c18512c76a9ea40329a6819fa9276e232679d834
# Successfully built subword-nmt
# Installing collected packages: subword-nmt
# Successfully installed subword-nmt-0.3.7

# %%
cd ParlAI/examples/
# Out:
# /content/ParlAI/examples

# %%
# %ls
# Out:
# base_train.py     extract_image_feature.py  remote.py
# build_dict.py     interactive.py            seq2seq_train_babi.py
# display_data.py   models/                   train_model.py
# display_model.py  profile_train.py
# eval_model.py     README.md

# %%
mkdir models

# %%
# !python train_model.py -t twitter -m seq2seq -mf models/HW2_model3 --dict-file models/HW2_model3.dict -emb glove --beam-size 40 --inference beam -opt adam -esz 300 -nl 4 -dr 0.3 -bi True -att local --attention-time pre --rnn-class lstm --decoder same -bs 16 -lr 0.001 --max-train-time 10800 --save-every-n-secs  300 -mcs all
# Out:
# [ Main ParlAI Arguments: ]
# [  batchsize: 16 ]
# [  datapath: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data ]
# [  datatype: train ]
# [  download_path: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/downloads ]
# [  dynamic_batching: None ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: twitter ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: models/HW2_model3 ]
# [ Training Loop Arguments: ]
# [  aggregate_micro: False ]
# [  display_examples: False ]
# [  eval_batchsize: None ]
# [  evaltask: None ]
# [  load_from_checkpoint: False ]
# [  max_train_time: 10800.0 ]
# [  metrics: all ]
# [  num_epochs: -1 ]
# [  save_after_valid: False ]
# [  save_every_n_secs: 300.0 ]
# [  short_final_eval: False ]
# [  validation_cutoff: 1.0 ]
# [  validation_every_n_epochs: -1 ]
# [  validation_every_n_secs: -1 ]
# [  validation_max_exs: -1 ]
# [  validation_metric: accuracy ]
# [  validation_metric_mode: None ]
# [  validation_patience: 10 ]
# [  validation_share_agent: False ]
# [ Tensorboard Arguments: ]
# [  tensorboard_log: False ]
# [ Dictionary Loop Arguments: ]
# [  dict_include_test: False ]
# [  dict_include_valid: False ]
# [  dict_maxexs: -1 ]
# [  log_every_n_secs: 2 ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: local ]
# [  attention_length: 48 ]
# [  attention_time: pre ]
# [  bidirectional: True ]
# [  decoder: same ]
# [  dropout: 0.3 ]
# [  embeddingsize: 300 ]
# [  hiddensize: 128 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 4 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: -1 ]
# [  beam_context_block_ngram: -1 ]
# [  beam_length_penalty: 0.65 ]
# [  beam_min_length: 1 ]
# [  beam_size: 40 ]
# [  compute_tokenized_bleu: False ]
# [  inference: beam ]
# [  skip_generation: False ]
# [  topk: 10 ]
# [  topp: 0.9 ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: glove ]
# [  force_fp16_tokens: False ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: False ]
# [  label_truncate: None ]
# [  no_cuda: False ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: (0.9, 0.999) ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 0.001 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: (0.7,) ]
# [  optimizer: adam ]
# [  weight_decay: None ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: models/HW2_model3.dict ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Learning Rate Scheduler: ]
# [  invsqrt_lr_decay_gamma: -1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  max_lr_steps: -1 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ building dictionary first... ]
# [ dictionary already built .]
# [ no model with opt yet at: models/HW2_model3(.opt) ]
# [ Using CUDA ]
# Dictionary: loading dictionary from models/HW2_model3.dict
# [ num words =  366522 ]
# tcmalloc: large alloc 2635227136 bytes == 0x6788e000 @  0x7fbce9859b6b 0x7fbce9879379 0x7fbc9231fb4a 0x7fbc923215fa 0x7fbc94a244af 0x7fbc94a2456d 0x7fbcdd49f1c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Initialized embeddings for 175884 tokens (48.0%) from glove.
# tcmalloc: large alloc 2635227136 bytes == 0x6788e000 @  0x7fbce9859b6b 0x7fbce9879379 0x7fbc9231fb4a 0x7fbc923215fa 0x7fbc94a244af 0x7fbc94a2456d 0x7fbcdd49f1c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Total parameters: 332704926
# Trainable parameters:  332704926
# [creating task(s): twitter]
# [loading parlAI text data:/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data/Twitter/train.txt]
# [ training... ]
# [ time:2.0s total_exs:80 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 5, 'gnorm': 3.009, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 65.31, 'token_acc': 0.0007541, 'nll_loss': 13.08, 'ppl': 478700.0}
# [ time:4.0s total_exs:176 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 11, 'gnorm': 2.8, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 72.62, 'token_acc': 0.04576, 'nll_loss': 12.1, 'ppl': 179900.0}
# [ time:6.0s total_exs:272 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 17, 'gnorm': 2.668, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 68.59, 'token_acc': 0.06408, 'nll_loss': 11.47, 'ppl': 96240.0}
# [ time:8.0s total_exs:368 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 23, 'gnorm': 2.066, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 68.78, 'token_acc': 0.05913, 'nll_loss': 11.48, 'ppl': 96370.0}
# [ time:11.0s total_exs:464 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 29, 'gnorm': 2.151, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 67.35, 'token_acc': 0.07156, 'nll_loss': 11.23, 'ppl': 75340.0}
# [ time:13.0s total_exs:560 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 35, 'gnorm': 2.025, 'clip': 1.0, 'gpu_mem_percent': 1.16, 'loss': 66.28, 'token_acc': 0.06876, 'nll_loss': 11.05, 'ppl': 63130.0}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:15.0s total_exs:656 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 40, 'gnorm': 2.015, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 66.26, 'token_acc': 0.06934, 'nll_loss': 11.09, 'ppl': 65580.0, 'total_skipped_batches': 1}
# [ time:17.0s total_exs:752 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 46, 'gnorm': 1.995, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 65.84, 'token_acc': 0.06922, 'nll_loss': 10.97, 'ppl': 58220.0, 'total_skipped_batches': 1}
# [ time:20.0s total_exs:848 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 52, 'gnorm': 1.912, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 64.55, 'token_acc': 0.06514, 'nll_loss': 10.76, 'ppl': 47020.0, 'total_skipped_batches': 1}
# [ time:22.0s total_exs:944 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 58, 'gnorm': 1.888, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 64.41, 'token_acc': 0.0673, 'nll_loss': 10.74, 'ppl': 45990.0, 'total_skipped_batches': 1}
# [ time:24.0s total_exs:1040 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 64, 'gnorm': 2.101, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 62.67, 'token_acc': 0.07029, 'nll_loss': 10.44, 'ppl': 34290.0, 'total_skipped_batches': 1}
# [ time:27.0s total_exs:1136 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 70, 'gnorm': 2.193, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 62.0, 'token_acc': 0.06729, 'nll_loss': 10.34, 'ppl': 30990.0, 'total_skipped_batches': 1}
# [ time:29.0s total_exs:1232 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 76, 'gnorm': 2.23, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 60.45, 'token_acc': 0.06811, 'nll_loss': 10.1, 'ppl': 24310.0, 'total_skipped_batches': 1}
# [ time:31.0s total_exs:1328 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 82, 'gnorm': 2.059, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 59.88, 'token_acc': 0.07484, 'nll_loss': 9.981, 'ppl': 21610.0, 'total_skipped_batches': 1}
# [ time:34.0s total_exs:1424 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 88, 'gnorm': 2.435, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 58.55, 'token_acc': 0.08231, 'nll_loss': 9.771, 'ppl': 17530.0, 'total_skipped_batches': 1}
# [ time:36.0s total_exs:1520 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 94, 'gnorm': 1.987, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 58.63, 'token_acc': 0.0618, 'nll_loss': 9.778, 'ppl': 17640.0, 'total_skipped_batches': 1}
# [ time:38.0s total_exs:1616 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 100, 'gnorm': 2.002, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 56.79, 'token_acc': 0.07766, 'nll_loss': 9.486, 'ppl': 13180.0, 'total_skipped_batches': 1}
# [ time:40.0s total_exs:1712 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 106, 'gnorm': 1.915, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 55.44, 'token_acc': 0.07601, 'nll_loss': 9.248, 'ppl': 10390.0, 'total_skipped_batches': 1}
# [ time:43.0s total_exs:1792 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 111, 'gnorm': 1.957, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 45.04, 'token_acc': 0.09979, 'nll_loss': 8.993, 'ppl': 8046.0, 'total_skipped_batches': 1}
# [ time:45.0s total_exs:1872 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 116, 'gnorm': 1.987, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 46.97, 'token_acc': 0.07093, 'nll_loss': 9.399, 'ppl': 12080.0, 'total_skipped_batches': 1}
# [ time:47.0s total_exs:1968 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 122, 'gnorm': 1.811, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 55.84, 'token_acc': 0.05924, 'nll_loss': 9.3, 'ppl': 10930.0, 'total_skipped_batches': 1}
# [ time:49.0s total_exs:2064 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 128, 'gnorm': 2.061, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 53.91, 'token_acc': 0.06096, 'nll_loss': 8.993, 'ppl': 8048.0, 'total_skipped_batches': 1}
# [ time:51.0s total_exs:2160 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 134, 'gnorm': 2.0, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 53.76, 'token_acc': 0.07125, 'nll_loss': 8.965, 'ppl': 7822.0, 'total_skipped_batches': 1}
# [ time:53.0s total_exs:2240 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 139, 'gnorm': 1.974, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 45.37, 'token_acc': 0.0607, 'nll_loss': 9.066, 'ppl': 8660.0, 'total_skipped_batches': 1}
# [ time:56.0s total_exs:2336 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 145, 'gnorm': 1.989, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 51.14, 'token_acc': 0.08631, 'nll_loss': 8.516, 'ppl': 4995.0, 'total_skipped_batches': 1}
# [ time:58.0s total_exs:2432 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 151, 'gnorm': 1.806, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 51.49, 'token_acc': 0.07806, 'nll_loss': 8.588, 'ppl': 5366.0, 'total_skipped_batches': 1}
# [ time:60.0s total_exs:2528 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 157, 'gnorm': 2.032, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 51.28, 'token_acc': 0.07604, 'nll_loss': 8.551, 'ppl': 5172.0, 'total_skipped_batches': 1}
# [ time:62.0s total_exs:2624 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 163, 'gnorm': 1.989, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 52.58, 'token_acc': 0.06906, 'nll_loss': 8.752, 'ppl': 6326.0, 'total_skipped_batches': 1}
# [ time:65.0s total_exs:2720 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 169, 'gnorm': 1.811, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 51.04, 'token_acc': 0.0671, 'nll_loss': 8.512, 'ppl': 4976.0, 'total_skipped_batches': 1}
# [ time:67.0s total_exs:2816 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 175, 'gnorm': 1.866, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 50.57, 'token_acc': 0.07971, 'nll_loss': 8.419, 'ppl': 4533.0, 'total_skipped_batches': 1}
# [ time:69.0s total_exs:2912 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 181, 'gnorm': 1.899, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 50.08, 'token_acc': 0.0892, 'nll_loss': 8.363, 'ppl': 4286.0, 'total_skipped_batches': 1}
# [ time:72.0s total_exs:3008 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 187, 'gnorm': 2.051, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 48.02, 'token_acc': 0.07584, 'nll_loss': 8.011, 'ppl': 3014.0, 'total_skipped_batches': 1}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:74.0s total_exs:3104 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 192, 'gnorm': 2.066, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 49.44, 'token_acc': 0.0867, 'nll_loss': 8.293, 'ppl': 3996.0, 'total_skipped_batches': 2}
# [ time:76.0s total_exs:3200 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 198, 'gnorm': 1.925, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 49.45, 'token_acc': 0.08252, 'nll_loss': 8.244, 'ppl': 3805.0, 'total_skipped_batches': 2}
# [ time:78.0s total_exs:3296 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 204, 'gnorm': 1.912, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 48.55, 'token_acc': 0.07577, 'nll_loss': 8.092, 'ppl': 3267.0, 'total_skipped_batches': 2}
# [ time:81.0s total_exs:3392 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 210, 'gnorm': 1.942, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 46.86, 'token_acc': 0.1004, 'nll_loss': 7.81, 'ppl': 2466.0, 'total_skipped_batches': 2}
# [ time:83.0s total_exs:3488 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 216, 'gnorm': 1.897, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 48.27, 'token_acc': 0.08672, 'nll_loss': 8.043, 'ppl': 3111.0, 'total_skipped_batches': 2}
# [ time:85.0s total_exs:3584 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 222, 'gnorm': 1.719, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 47.68, 'token_acc': 0.08065, 'nll_loss': 7.962, 'ppl': 2869.0, 'total_skipped_batches': 2}
# [ time:88.0s total_exs:3680 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 228, 'gnorm': 2.205, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 46.42, 'token_acc': 0.09277, 'nll_loss': 7.692, 'ppl': 2192.0, 'total_skipped_batches': 2}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:90.0s total_exs:3776 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 233, 'gnorm': 1.811, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 45.85, 'token_acc': 0.1055, 'nll_loss': 7.701, 'ppl': 2210.0, 'total_skipped_batches': 3}
# [ time:92.0s total_exs:3856 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 238, 'gnorm': 1.756, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 38.74, 'token_acc': 0.09131, 'nll_loss': 7.751, 'ppl': 2325.0, 'total_skipped_batches': 3}
# [ time:94.0s total_exs:3952 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 244, 'gnorm': 1.834, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 46.14, 'token_acc': 0.09779, 'nll_loss': 7.69, 'ppl': 2186.0, 'total_skipped_batches': 3}
# [ time:96.0s total_exs:4048 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 250, 'gnorm': 1.713, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 45.66, 'token_acc': 0.1034, 'nll_loss': 7.62, 'ppl': 2038.0, 'total_skipped_batches': 3}
# [ time:99.0s total_exs:4144 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 256, 'gnorm': 1.825, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 45.59, 'token_acc': 0.1043, 'nll_loss': 7.606, 'ppl': 2011.0, 'total_skipped_batches': 3}
# [ time:101.0s total_exs:4240 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 262, 'gnorm': 1.817, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 46.18, 'token_acc': 0.09848, 'nll_loss': 7.687, 'ppl': 2179.0, 'total_skipped_batches': 3}
# [ time:103.0s total_exs:4336 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 268, 'gnorm': 1.739, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 44.98, 'token_acc': 0.09563, 'nll_loss': 7.498, 'ppl': 1804.0, 'total_skipped_batches': 3}
# [ time:106.0s total_exs:4432 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 274, 'gnorm': 1.872, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 44.53, 'token_acc': 0.1171, 'nll_loss': 7.436, 'ppl': 1696.0, 'total_skipped_batches': 3}
# [ time:108.0s total_exs:4528 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 280, 'gnorm': 1.895, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 43.36, 'token_acc': 0.121, 'nll_loss': 7.228, 'ppl': 1377.0, 'total_skipped_batches': 3}
# [ time:111.0s total_exs:4624 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 286, 'gnorm': 1.858, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 43.23, 'token_acc': 0.1176, 'nll_loss': 7.227, 'ppl': 1376.0, 'total_skipped_batches': 3}
# [ time:113.0s total_exs:4720 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 292, 'gnorm': 1.813, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 44.78, 'token_acc': 0.1009, 'nll_loss': 7.461, 'ppl': 1739.0, 'total_skipped_batches': 3}
# [ time:115.0s total_exs:4816 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 298, 'gnorm': 1.727, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 43.16, 'token_acc': 0.1025, 'nll_loss': 7.189, 'ppl': 1324.0, 'total_skipped_batches': 3}
# [ time:117.0s total_exs:4912 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 304, 'gnorm': 1.826, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 43.25, 'token_acc': 0.0982, 'nll_loss': 7.212, 'ppl': 1356.0, 'total_skipped_batches': 3}
# [ time:120.0s total_exs:5008 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 310, 'gnorm': 1.661, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 45.38, 'token_acc': 0.0811, 'nll_loss': 7.57, 'ppl': 1939.0, 'total_skipped_batches': 3}
# [ time:122.0s total_exs:5104 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 316, 'gnorm': 1.844, 'clip': 1.0, 'gpu_mem_percent': 1.37, 'loss': 43.4, 'token_acc': 0.1199, 'nll_loss': 7.236, 'ppl': 1388.0, 'total_skipped_batches': 3}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:125.0s total_exs:5200 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 321, 'gnorm': 1.7, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 43.25, 'token_acc': 0.1218, 'nll_loss': 7.276, 'ppl': 1445.0, 'total_skipped_batches': 4}
# [ time:127.0s total_exs:5296 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 327, 'gnorm': 1.77, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 43.34, 'token_acc': 0.1239, 'nll_loss': 7.211, 'ppl': 1354.0, 'total_skipped_batches': 4}
# [ time:129.0s total_exs:5376 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 332, 'gnorm': 1.672, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 36.31, 'token_acc': 0.1233, 'nll_loss': 7.261, 'ppl': 1423.0, 'total_skipped_batches': 4}
# [ time:131.0s total_exs:5472 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 338, 'gnorm': 1.684, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 44.37, 'token_acc': 0.1067, 'nll_loss': 7.373, 'ppl': 1592.0, 'total_skipped_batches': 4}
# [ time:133.0s total_exs:5568 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 344, 'gnorm': 1.789, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 42.92, 'token_acc': 0.0981, 'nll_loss': 7.155, 'ppl': 1281.0, 'total_skipped_batches': 4}
# [ time:136.0s total_exs:5664 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 350, 'gnorm': 1.721, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 43.34, 'token_acc': 0.1058, 'nll_loss': 7.225, 'ppl': 1374.0, 'total_skipped_batches': 4}
# [ time:138.0s total_exs:5744 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 355, 'gnorm': 1.724, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 34.9, 'token_acc': 0.1123, 'nll_loss': 6.979, 'ppl': 1074.0, 'total_skipped_batches': 4}
# [ time:140.0s total_exs:5840 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 361, 'gnorm': 1.759, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 44.08, 'token_acc': 0.1105, 'nll_loss': 7.345, 'ppl': 1548.0, 'total_skipped_batches': 4}
# [ time:142.0s total_exs:5936 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 367, 'gnorm': 1.632, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 42.77, 'token_acc': 0.115, 'nll_loss': 7.114, 'ppl': 1229.0, 'total_skipped_batches': 4}
# [ time:145.0s total_exs:6032 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 373, 'gnorm': 1.857, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 43.86, 'token_acc': 0.1132, 'nll_loss': 7.305, 'ppl': 1487.0, 'total_skipped_batches': 4}
# [ time:147.0s total_exs:6128 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 379, 'gnorm': 1.801, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 42.76, 'token_acc': 0.1132, 'nll_loss': 7.137, 'ppl': 1258.0, 'total_skipped_batches': 4}
# [ time:149.0s total_exs:6224 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 385, 'gnorm': 1.759, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.96, 'token_acc': 0.1278, 'nll_loss': 6.992, 'ppl': 1088.0, 'total_skipped_batches': 4}
# [ time:152.0s total_exs:6320 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 391, 'gnorm': 1.755, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 42.37, 'token_acc': 0.1225, 'nll_loss': 7.059, 'ppl': 1163.0, 'total_skipped_batches': 4}
# [ time:154.0s total_exs:6400 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 396, 'gnorm': 1.594, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 35.27, 'token_acc': 0.1237, 'nll_loss': 7.059, 'ppl': 1163.0, 'total_skipped_batches': 4}
# [ time:156.0s total_exs:6496 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 402, 'gnorm': 1.797, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.59, 'token_acc': 0.1252, 'nll_loss': 6.931, 'ppl': 1024.0, 'total_skipped_batches': 4}
# [ time:158.0s total_exs:6576 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 407, 'gnorm': 1.705, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 35.37, 'token_acc': 0.1261, 'nll_loss': 7.078, 'ppl': 1186.0, 'total_skipped_batches': 4}
# [ time:161.0s total_exs:6672 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 413, 'gnorm': 1.672, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.31, 'token_acc': 0.1178, 'nll_loss': 6.898, 'ppl': 989.9, 'total_skipped_batches': 4}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:163.0s total_exs:6768 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 418, 'gnorm': 1.682, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 40.77, 'token_acc': 0.1329, 'nll_loss': 6.888, 'ppl': 980.2, 'total_skipped_batches': 5}
# [ time:165.0s total_exs:6848 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 423, 'gnorm': 1.915, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 35.36, 'token_acc': 0.1107, 'nll_loss': 7.077, 'ppl': 1184.0, 'total_skipped_batches': 5}
# [ time:167.0s total_exs:6944 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 429, 'gnorm': 1.859, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.33, 'token_acc': 0.1299, 'nll_loss': 6.838, 'ppl': 932.5, 'total_skipped_batches': 5}
# [ time:169.0s total_exs:7040 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 435, 'gnorm': 1.608, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 42.92, 'token_acc': 0.1062, 'nll_loss': 7.147, 'ppl': 1270.0, 'total_skipped_batches': 5}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:172.0s total_exs:7136 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 440, 'gnorm': 1.547, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 41.05, 'token_acc': 0.1362, 'nll_loss': 6.887, 'ppl': 979.8, 'total_skipped_batches': 6}
# [ time:174.0s total_exs:7232 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 446, 'gnorm': 1.633, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 42.0, 'token_acc': 0.124, 'nll_loss': 7.006, 'ppl': 1104.0, 'total_skipped_batches': 6}
# [ time:176.0s total_exs:7312 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 451, 'gnorm': 1.674, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 34.34, 'token_acc': 0.1262, 'nll_loss': 6.874, 'ppl': 966.6, 'total_skipped_batches': 6}
# [ time:178.0s total_exs:7408 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 457, 'gnorm': 1.732, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 41.94, 'token_acc': 0.1213, 'nll_loss': 6.986, 'ppl': 1082.0, 'total_skipped_batches': 6}
# [ time:180.0s total_exs:7504 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 463, 'gnorm': 1.719, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 41.94, 'token_acc': 0.1221, 'nll_loss': 6.988, 'ppl': 1083.0, 'total_skipped_batches': 6}
# [ time:183.0s total_exs:7600 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 469, 'gnorm': 1.714, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 39.91, 'token_acc': 0.1486, 'nll_loss': 6.66, 'ppl': 780.6, 'total_skipped_batches': 6}
# [ time:185.0s total_exs:7680 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 474, 'gnorm': 1.636, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 34.04, 'token_acc': 0.1288, 'nll_loss': 6.798, 'ppl': 895.9, 'total_skipped_batches': 6}
# [ time:187.0s total_exs:7760 epochs:0.0 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 479, 'gnorm': 1.806, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 34.21, 'token_acc': 0.129, 'nll_loss': 6.828, 'ppl': 923.3, 'total_skipped_batches': 6}
# [ time:189.0s total_exs:7856 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 485, 'gnorm': 1.627, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 39.97, 'token_acc': 0.1263, 'nll_loss': 6.67, 'ppl': 788.5, 'total_skipped_batches': 6}
# [ time:192.0s total_exs:7952 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 491, 'gnorm': 1.721, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.42, 'token_acc': 0.1263, 'nll_loss': 6.897, 'ppl': 989.4, 'total_skipped_batches': 6}
# [ time:194.0s total_exs:8048 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 497, 'gnorm': 1.699, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.44, 'token_acc': 0.1245, 'nll_loss': 6.715, 'ppl': 824.9, 'total_skipped_batches': 6}
# [ time:196.0s total_exs:8144 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 503, 'gnorm': 1.697, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.95, 'token_acc': 0.1215, 'nll_loss': 6.811, 'ppl': 907.9, 'total_skipped_batches': 6}
# [ time:199.0s total_exs:8240 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 509, 'gnorm': 1.637, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.45, 'token_acc': 0.1235, 'nll_loss': 6.923, 'ppl': 1015.0, 'total_skipped_batches': 6}
# [ time:201.0s total_exs:8336 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 515, 'gnorm': 1.657, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.92, 'token_acc': 0.1256, 'nll_loss': 6.813, 'ppl': 909.9, 'total_skipped_batches': 6}
# [ time:203.0s total_exs:8432 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 521, 'gnorm': 1.509, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.55, 'token_acc': 0.1317, 'nll_loss': 6.761, 'ppl': 863.6, 'total_skipped_batches': 6}
# [ time:205.0s total_exs:8528 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 527, 'gnorm': 1.736, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.0, 'token_acc': 0.1318, 'nll_loss': 6.646, 'ppl': 769.6, 'total_skipped_batches': 6}
# [ time:208.0s total_exs:8624 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 533, 'gnorm': 1.548, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 39.36, 'token_acc': 0.1328, 'nll_loss': 6.571, 'ppl': 713.9, 'total_skipped_batches': 6}
# [ time:210.0s total_exs:8720 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 539, 'gnorm': 1.702, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.4, 'token_acc': 0.1398, 'nll_loss': 6.758, 'ppl': 861.0, 'total_skipped_batches': 6}
# [ time:212.0s total_exs:8816 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 545, 'gnorm': 1.712, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.04, 'token_acc': 0.142, 'nll_loss': 6.657, 'ppl': 777.9, 'total_skipped_batches': 6}
# [ time:215.0s total_exs:8912 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 551, 'gnorm': 1.562, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.15, 'token_acc': 0.1369, 'nll_loss': 6.698, 'ppl': 810.4, 'total_skipped_batches': 6}
# [ time:217.0s total_exs:9008 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 557, 'gnorm': 1.67, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.51, 'token_acc': 0.1435, 'nll_loss': 6.76, 'ppl': 862.2, 'total_skipped_batches': 6}
# [ time:219.0s total_exs:9104 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 563, 'gnorm': 1.745, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.99, 'token_acc': 0.1234, 'nll_loss': 6.851, 'ppl': 945.0, 'total_skipped_batches': 6}
# [ time:222.0s total_exs:9200 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 569, 'gnorm': 1.637, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 41.25, 'token_acc': 0.1226, 'nll_loss': 6.869, 'ppl': 962.4, 'total_skipped_batches': 6}
# [ time:224.0s total_exs:9296 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 575, 'gnorm': 1.654, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.36, 'token_acc': 0.1401, 'nll_loss': 6.724, 'ppl': 832.4, 'total_skipped_batches': 6}
# [ time:226.0s total_exs:9392 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 581, 'gnorm': 1.649, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 39.13, 'token_acc': 0.1331, 'nll_loss': 6.531, 'ppl': 686.1, 'total_skipped_batches': 6}
# [ time:228.0s total_exs:9488 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 587, 'gnorm': 1.708, 'clip': 1.0, 'gpu_mem_percent': 1.36, 'loss': 40.25, 'token_acc': 0.1257, 'nll_loss': 6.739, 'ppl': 845.0, 'total_skipped_batches': 6}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:231.0s total_exs:9584 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 592, 'gnorm': 1.765, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 40.61, 'token_acc': 0.1293, 'nll_loss': 6.84, 'ppl': 934.1, 'total_skipped_batches': 7}
# [ time:233.0s total_exs:9680 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 598, 'gnorm': 1.752, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 38.76, 'token_acc': 0.1534, 'nll_loss': 6.461, 'ppl': 639.9, 'total_skipped_batches': 7}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:235.0s total_exs:9776 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 603, 'gnorm': 1.708, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 39.62, 'token_acc': 0.1471, 'nll_loss': 6.676, 'ppl': 792.8, 'total_skipped_batches': 8}
# [ time:237.0s total_exs:9872 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 609, 'gnorm': 1.643, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 38.8, 'token_acc': 0.1408, 'nll_loss': 6.461, 'ppl': 639.5, 'total_skipped_batches': 8}
# [ time:240.0s total_exs:9968 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 615, 'gnorm': 1.572, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 39.58, 'token_acc': 0.1471, 'nll_loss': 6.597, 'ppl': 733.0, 'total_skipped_batches': 8}
# [ time:242.0s total_exs:10064 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 621, 'gnorm': 1.674, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 39.42, 'token_acc': 0.1419, 'nll_loss': 6.581, 'ppl': 721.5, 'total_skipped_batches': 8}
# [ time:244.0s total_exs:10160 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 627, 'gnorm': 1.719, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 40.17, 'token_acc': 0.1273, 'nll_loss': 6.665, 'ppl': 784.7, 'total_skipped_batches': 8}
# [ time:246.0s total_exs:10256 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 633, 'gnorm': 1.574, 'clip': 1.0, 'gpu_mem_percent': 1.29, 'loss': 39.47, 'token_acc': 0.1463, 'nll_loss': 6.603, 'ppl': 737.1, 'total_skipped_batches': 8}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:249.0s total_exs:10352 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 638, 'gnorm': 1.637, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.38, 'token_acc': 0.1346, 'nll_loss': 6.648, 'ppl': 771.3, 'total_skipped_batches': 9}
# [ time:251.0s total_exs:10448 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 644, 'gnorm': 1.652, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.65, 'token_acc': 0.1525, 'nll_loss': 6.606, 'ppl': 739.3, 'total_skipped_batches': 9}
# [ time:253.0s total_exs:10544 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 650, 'gnorm': 1.642, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 40.9, 'token_acc': 0.1501, 'nll_loss': 6.809, 'ppl': 905.9, 'total_skipped_batches': 9}
# [ time:256.0s total_exs:10640 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 656, 'gnorm': 1.754, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.39, 'token_acc': 0.1397, 'nll_loss': 6.586, 'ppl': 725.0, 'total_skipped_batches': 9}
# [ time:258.0s total_exs:10736 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 662, 'gnorm': 1.594, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.63, 'token_acc': 0.1399, 'nll_loss': 6.604, 'ppl': 738.2, 'total_skipped_batches': 9}
# [ time:260.0s total_exs:10832 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 668, 'gnorm': 1.603, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.96, 'token_acc': 0.1299, 'nll_loss': 6.655, 'ppl': 776.7, 'total_skipped_batches': 9}
# [ time:263.0s total_exs:10928 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 674, 'gnorm': 1.509, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 40.52, 'token_acc': 0.1339, 'nll_loss': 6.755, 'ppl': 858.1, 'total_skipped_batches': 9}
# [ time:265.0s total_exs:11024 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 680, 'gnorm': 1.625, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.69, 'token_acc': 0.135, 'nll_loss': 6.616, 'ppl': 747.0, 'total_skipped_batches': 9}
# [ time:267.0s total_exs:11120 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 686, 'gnorm': 1.582, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 40.63, 'token_acc': 0.1365, 'nll_loss': 6.772, 'ppl': 872.9, 'total_skipped_batches': 9}
# [ time:270.0s total_exs:11216 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 692, 'gnorm': 1.604, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.05, 'token_acc': 0.1527, 'nll_loss': 6.493, 'ppl': 660.6, 'total_skipped_batches': 9}
# [ time:272.0s total_exs:11312 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 698, 'gnorm': 1.496, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.72, 'token_acc': 0.1655, 'nll_loss': 6.431, 'ppl': 620.6, 'total_skipped_batches': 9}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:274.0s total_exs:11408 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 703, 'gnorm': 1.533, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.78, 'token_acc': 0.1364, 'nll_loss': 6.698, 'ppl': 810.6, 'total_skipped_batches': 10}
# [ time:277.0s total_exs:11504 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 709, 'gnorm': 1.537, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.54, 'token_acc': 0.1394, 'nll_loss': 6.566, 'ppl': 710.5, 'total_skipped_batches': 10}
# [ time:279.0s total_exs:11600 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 715, 'gnorm': 1.578, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.91, 'token_acc': 0.1479, 'nll_loss': 6.666, 'ppl': 785.1, 'total_skipped_batches': 10}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:281.0s total_exs:11696 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 720, 'gnorm': 1.592, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.69, 'token_acc': 0.1515, 'nll_loss': 6.533, 'ppl': 687.6, 'total_skipped_batches': 11}
# [ time:283.0s total_exs:11792 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 726, 'gnorm': 1.61, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.94, 'token_acc': 0.156, 'nll_loss': 6.482, 'ppl': 653.4, 'total_skipped_batches': 11}
# [ time:286.0s total_exs:11888 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 732, 'gnorm': 1.57, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.24, 'token_acc': 0.1438, 'nll_loss': 6.387, 'ppl': 593.9, 'total_skipped_batches': 11}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:288.0s total_exs:11984 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 737, 'gnorm': 1.537, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.32, 'token_acc': 0.1621, 'nll_loss': 6.287, 'ppl': 537.4, 'total_skipped_batches': 12}
# [ time:290.0s total_exs:12080 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 743, 'gnorm': 1.558, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.96, 'token_acc': 0.1524, 'nll_loss': 6.665, 'ppl': 784.4, 'total_skipped_batches': 12}
# [ time:292.0s total_exs:12176 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 749, 'gnorm': 1.6, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.82, 'token_acc': 0.1267, 'nll_loss': 6.638, 'ppl': 763.4, 'total_skipped_batches': 12}
# [ time:294.0s total_exs:12272 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 755, 'gnorm': 1.552, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.81, 'token_acc': 0.1468, 'nll_loss': 6.63, 'ppl': 757.2, 'total_skipped_batches': 12}
# [ time:297.0s total_exs:12368 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 761, 'gnorm': 1.677, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.52, 'token_acc': 0.1436, 'nll_loss': 6.429, 'ppl': 619.4, 'total_skipped_batches': 12}
# [ time:299.0s total_exs:12464 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 767, 'gnorm': 1.515, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.12, 'token_acc': 0.1465, 'nll_loss': 6.352, 'ppl': 573.4, 'total_skipped_batches': 12}
# [ saving model checkpoint: models/HW2_model3.checkpoint
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:403.0s total_exs:12512 epochs:0.0 ] {'exs': 48, 'lr': 0.001, 'total_train_updates': 769, 'gnorm': 1.455, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 19.1, 'token_acc': 0.16, 'nll_loss': 6.532, 'ppl': 686.9, 'total_skipped_batches': 13}
# [ time:405.0s total_exs:12608 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 775, 'gnorm': 1.533, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.77, 'token_acc': 0.1497, 'nll_loss': 6.455, 'ppl': 636.2, 'total_skipped_batches': 13}
# [ time:408.0s total_exs:12704 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 781, 'gnorm': 1.525, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.62, 'token_acc': 0.1277, 'nll_loss': 6.601, 'ppl': 735.6, 'total_skipped_batches': 13}
# [ time:410.0s total_exs:12800 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 787, 'gnorm': 1.52, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.1, 'token_acc': 0.1347, 'nll_loss': 6.518, 'ppl': 677.2, 'total_skipped_batches': 13}
# [ time:412.0s total_exs:12896 epochs:0.0 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 793, 'gnorm': 1.472, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.84, 'token_acc': 0.1396, 'nll_loss': 6.673, 'ppl': 790.5, 'total_skipped_batches': 13}
# [ time:415.0s total_exs:12992 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 799, 'gnorm': 1.659, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.51, 'token_acc': 0.1446, 'nll_loss': 6.441, 'ppl': 627.2, 'total_skipped_batches': 13}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:417.0s total_exs:13088 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 804, 'gnorm': 1.584, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.02, 'token_acc': 0.1495, 'nll_loss': 6.433, 'ppl': 621.9, 'total_skipped_batches': 14}
# [ time:419.0s total_exs:13184 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 810, 'gnorm': 1.66, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.08, 'token_acc': 0.1434, 'nll_loss': 6.517, 'ppl': 676.6, 'total_skipped_batches': 14}
# [ time:421.0s total_exs:13280 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 816, 'gnorm': 1.564, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.17, 'token_acc': 0.161, 'nll_loss': 6.327, 'ppl': 559.6, 'total_skipped_batches': 14}
# [ time:424.0s total_exs:13376 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 822, 'gnorm': 1.643, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.4, 'token_acc': 0.1325, 'nll_loss': 6.559, 'ppl': 705.5, 'total_skipped_batches': 14}
# [ time:426.0s total_exs:13472 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 828, 'gnorm': 1.602, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.52, 'token_acc': 0.1678, 'nll_loss': 6.232, 'ppl': 508.5, 'total_skipped_batches': 14}
# [ time:428.0s total_exs:13568 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 834, 'gnorm': 1.562, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.14, 'token_acc': 0.1432, 'nll_loss': 6.529, 'ppl': 684.9, 'total_skipped_batches': 14}
# [ time:430.0s total_exs:13664 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 840, 'gnorm': 1.529, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.17, 'token_acc': 0.1288, 'nll_loss': 6.534, 'ppl': 688.3, 'total_skipped_batches': 14}
# [ time:432.0s total_exs:13744 epochs:0.01 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 845, 'gnorm': 1.628, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 32.34, 'token_acc': 0.1563, 'nll_loss': 6.49, 'ppl': 658.3, 'total_skipped_batches': 14}
# [ time:435.0s total_exs:13840 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 851, 'gnorm': 1.545, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.32, 'token_acc': 0.1602, 'nll_loss': 6.387, 'ppl': 594.3, 'total_skipped_batches': 14}
# [ time:437.0s total_exs:13936 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 857, 'gnorm': 1.528, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.79, 'token_acc': 0.1507, 'nll_loss': 6.309, 'ppl': 549.7, 'total_skipped_batches': 14}
# [ time:439.0s total_exs:14032 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 863, 'gnorm': 1.61, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.48, 'token_acc': 0.1547, 'nll_loss': 6.24, 'ppl': 512.7, 'total_skipped_batches': 14}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:441.0s total_exs:14128 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 868, 'gnorm': 1.606, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 40.06, 'token_acc': 0.1393, 'nll_loss': 6.77, 'ppl': 871.6, 'total_skipped_batches': 15}
# [ time:444.0s total_exs:14224 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 874, 'gnorm': 1.528, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 39.29, 'token_acc': 0.1441, 'nll_loss': 6.553, 'ppl': 701.6, 'total_skipped_batches': 15}
# [ time:446.0s total_exs:14320 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 880, 'gnorm': 1.633, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.17, 'token_acc': 0.1519, 'nll_loss': 6.347, 'ppl': 570.5, 'total_skipped_batches': 15}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:448.0s total_exs:14416 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 885, 'gnorm': 1.56, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 36.92, 'token_acc': 0.1581, 'nll_loss': 6.284, 'ppl': 535.8, 'total_skipped_batches': 16}
# [ time:451.0s total_exs:14512 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 891, 'gnorm': 1.59, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.84, 'token_acc': 0.1536, 'nll_loss': 6.455, 'ppl': 635.8, 'total_skipped_batches': 16}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:453.0s total_exs:14608 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 896, 'gnorm': 1.491, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.26, 'token_acc': 0.1624, 'nll_loss': 6.276, 'ppl': 531.8, 'total_skipped_batches': 17}
# [ time:455.0s total_exs:14704 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 902, 'gnorm': 1.615, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.59, 'token_acc': 0.13, 'nll_loss': 6.432, 'ppl': 621.4, 'total_skipped_batches': 17}
# [ time:457.0s total_exs:14800 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 908, 'gnorm': 1.51, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.27, 'token_acc': 0.1434, 'nll_loss': 6.392, 'ppl': 597.2, 'total_skipped_batches': 17}
# [ time:459.0s total_exs:14880 epochs:0.01 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 913, 'gnorm': 1.521, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 32.24, 'token_acc': 0.1426, 'nll_loss': 6.438, 'ppl': 625.1, 'total_skipped_batches': 17}
# [ time:462.0s total_exs:14976 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 919, 'gnorm': 1.654, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.42, 'token_acc': 0.145, 'nll_loss': 6.403, 'ppl': 603.5, 'total_skipped_batches': 17}
# [ time:464.0s total_exs:15072 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 925, 'gnorm': 1.505, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 37.13, 'token_acc': 0.1571, 'nll_loss': 6.193, 'ppl': 489.3, 'total_skipped_batches': 17}
# [ time:466.0s total_exs:15168 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 931, 'gnorm': 1.5, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.23, 'token_acc': 0.1582, 'nll_loss': 6.372, 'ppl': 585.1, 'total_skipped_batches': 17}
# [ time:469.0s total_exs:15264 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 937, 'gnorm': 1.486, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.23, 'token_acc': 0.1526, 'nll_loss': 6.373, 'ppl': 586.0, 'total_skipped_batches': 17}
# [ time:471.0s total_exs:15360 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 943, 'gnorm': 1.488, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.24, 'token_acc': 0.1548, 'nll_loss': 6.377, 'ppl': 588.1, 'total_skipped_batches': 17}
# [ time:473.0s total_exs:15456 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 949, 'gnorm': 1.448, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 36.8, 'token_acc': 0.1738, 'nll_loss': 6.135, 'ppl': 461.7, 'total_skipped_batches': 17}
# [ time:475.0s total_exs:15536 epochs:0.01 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 954, 'gnorm': 1.558, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 31.26, 'token_acc': 0.149, 'nll_loss': 6.263, 'ppl': 524.8, 'total_skipped_batches': 17}
# [ time:478.0s total_exs:15632 epochs:0.01 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 960, 'gnorm': 1.597, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 38.0, 'token_acc': 0.1582, 'nll_loss': 6.339, 'ppl': 566.4, 'total_skipped_batches': 17}
# [ time:480.0s total_exs:15712 epochs:0.01 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 965, 'gnorm': 1.523, 'clip': 1.0, 'gpu_mem_percent': 1.31, 'loss': 32.03, 'token_acc': 0.1532, 'nll_loss': 6.391, 'ppl': 596.3, 'total_skipped_batches': 17}
# ...
# [ time:10671.0s total_exs:330896 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20488, 'gnorm': 1.29, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 33.32, 'token_acc': 0.1926, 'nll_loss': 5.55, 'ppl': 257.2, 'total_skipped_batches': 193}
# [ time:10673.0s total_exs:330992 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20494, 'gnorm': 1.343, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.25, 'token_acc': 0.2021, 'nll_loss': 5.371, 'ppl': 215.0, 'total_skipped_batches': 193}
# [ time:10676.0s total_exs:331088 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20500, 'gnorm': 1.219, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.99, 'token_acc': 0.1862, 'nll_loss': 5.479, 'ppl': 239.6, 'total_skipped_batches': 193}
# [ time:10678.0s total_exs:331184 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20506, 'gnorm': 1.166, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.52, 'token_acc': 0.239, 'nll_loss': 5.235, 'ppl': 187.7, 'total_skipped_batches': 193}
# [ time:10680.0s total_exs:331280 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20512, 'gnorm': 1.341, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.31, 'token_acc': 0.1963, 'nll_loss': 5.373, 'ppl': 215.5, 'total_skipped_batches': 193}
# [ time:10682.0s total_exs:331360 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20517, 'gnorm': 1.24, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 26.46, 'token_acc': 0.2129, 'nll_loss': 5.291, 'ppl': 198.5, 'total_skipped_batches': 193}
# [ time:10685.0s total_exs:331456 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20523, 'gnorm': 1.215, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.98, 'token_acc': 0.2115, 'nll_loss': 5.169, 'ppl': 175.7, 'total_skipped_batches': 193}
# [ time:10687.0s total_exs:331552 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20529, 'gnorm': 1.211, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.49, 'token_acc': 0.2268, 'nll_loss': 5.241, 'ppl': 188.9, 'total_skipped_batches': 193}
# [ time:10689.0s total_exs:331648 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20535, 'gnorm': 1.246, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.46, 'token_acc': 0.2279, 'nll_loss': 5.241, 'ppl': 188.9, 'total_skipped_batches': 193}
# [ time:10692.0s total_exs:331744 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20541, 'gnorm': 1.166, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.54, 'token_acc': 0.2176, 'nll_loss': 5.262, 'ppl': 192.9, 'total_skipped_batches': 193}
# [ time:10694.0s total_exs:331840 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20547, 'gnorm': 1.299, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.48, 'token_acc': 0.2026, 'nll_loss': 5.408, 'ppl': 223.2, 'total_skipped_batches': 193}
# [ time:10696.0s total_exs:331936 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20553, 'gnorm': 1.249, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.52, 'token_acc': 0.2262, 'nll_loss': 5.256, 'ppl': 191.7, 'total_skipped_batches': 193}
# [ time:10698.0s total_exs:332016 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20558, 'gnorm': 1.256, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 26.15, 'token_acc': 0.2239, 'nll_loss': 5.233, 'ppl': 187.4, 'total_skipped_batches': 193}
# [ time:10700.0s total_exs:332112 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20564, 'gnorm': 1.281, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.61, 'token_acc': 0.1958, 'nll_loss': 5.442, 'ppl': 231.0, 'total_skipped_batches': 193}
# [ time:10703.0s total_exs:332208 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20570, 'gnorm': 1.262, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.76, 'token_acc': 0.2176, 'nll_loss': 5.292, 'ppl': 198.8, 'total_skipped_batches': 193}
# [ time:10705.0s total_exs:332304 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20576, 'gnorm': 1.318, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.84, 'token_acc': 0.2131, 'nll_loss': 5.472, 'ppl': 237.9, 'total_skipped_batches': 193}
# [ time:10707.0s total_exs:332400 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20582, 'gnorm': 1.306, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.06, 'token_acc': 0.2558, 'nll_loss': 5.013, 'ppl': 150.4, 'total_skipped_batches': 193}
# [ time:10710.0s total_exs:332496 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20588, 'gnorm': 1.205, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.99, 'token_acc': 0.2115, 'nll_loss': 5.321, 'ppl': 204.6, 'total_skipped_batches': 193}
# [ time:10712.0s total_exs:332592 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20594, 'gnorm': 1.234, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.15, 'token_acc': 0.2161, 'nll_loss': 5.181, 'ppl': 177.9, 'total_skipped_batches': 193}
# [ time:10714.0s total_exs:332688 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20600, 'gnorm': 1.242, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.28, 'token_acc': 0.2165, 'nll_loss': 5.374, 'ppl': 215.8, 'total_skipped_batches': 193}
# [ time:10717.0s total_exs:332784 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20606, 'gnorm': 1.265, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.28, 'token_acc': 0.216, 'nll_loss': 5.378, 'ppl': 216.5, 'total_skipped_batches': 193}
# [ time:10719.0s total_exs:332880 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20612, 'gnorm': 1.428, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.12, 'token_acc': 0.2246, 'nll_loss': 5.208, 'ppl': 182.7, 'total_skipped_batches': 193}
# [ time:10721.0s total_exs:332960 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20617, 'gnorm': 1.223, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 25.34, 'token_acc': 0.2556, 'nll_loss': 5.017, 'ppl': 150.9, 'total_skipped_batches': 193}
# [ time:10724.0s total_exs:333056 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20623, 'gnorm': 1.198, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.36, 'token_acc': 0.1998, 'nll_loss': 5.367, 'ppl': 214.3, 'total_skipped_batches': 193}
# [ time:10726.0s total_exs:333152 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20629, 'gnorm': 1.342, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.25, 'token_acc': 0.2323, 'nll_loss': 5.234, 'ppl': 187.5, 'total_skipped_batches': 193}
# [ time:10728.0s total_exs:333248 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20635, 'gnorm': 1.215, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.06, 'token_acc': 0.2463, 'nll_loss': 5.029, 'ppl': 152.7, 'total_skipped_batches': 193}
# [ time:10731.0s total_exs:333344 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20641, 'gnorm': 1.245, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.73, 'token_acc': 0.2342, 'nll_loss': 5.308, 'ppl': 202.0, 'total_skipped_batches': 193}
# [ time:10733.0s total_exs:333440 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20647, 'gnorm': 1.29, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.66, 'token_acc': 0.1838, 'nll_loss': 5.463, 'ppl': 235.8, 'total_skipped_batches': 193}
# [ time:10735.0s total_exs:333536 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20653, 'gnorm': 1.272, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.52, 'token_acc': 0.2127, 'nll_loss': 5.264, 'ppl': 193.3, 'total_skipped_batches': 193}
# [ time:10737.0s total_exs:333632 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20659, 'gnorm': 1.213, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.24, 'token_acc': 0.2213, 'nll_loss': 5.204, 'ppl': 181.9, 'total_skipped_batches': 193}
# [ time:10740.0s total_exs:333728 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20665, 'gnorm': 1.214, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.23, 'token_acc': 0.227, 'nll_loss': 5.044, 'ppl': 155.1, 'total_skipped_batches': 193}
# [ time:10742.0s total_exs:333808 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20670, 'gnorm': 1.21, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 25.16, 'token_acc': 0.2459, 'nll_loss': 5.039, 'ppl': 154.3, 'total_skipped_batches': 193}
# [ time:10744.0s total_exs:333904 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20676, 'gnorm': 1.197, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.42, 'token_acc': 0.2228, 'nll_loss': 5.394, 'ppl': 220.1, 'total_skipped_batches': 193}
# [ time:10746.0s total_exs:334000 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20682, 'gnorm': 1.222, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.35, 'token_acc': 0.2215, 'nll_loss': 5.399, 'ppl': 221.2, 'total_skipped_batches': 193}
# [ time:10749.0s total_exs:334096 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20688, 'gnorm': 1.316, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.81, 'token_acc': 0.2024, 'nll_loss': 5.279, 'ppl': 196.2, 'total_skipped_batches': 193}
# [ time:10751.0s total_exs:334192 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20694, 'gnorm': 1.295, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.47, 'token_acc': 0.216, 'nll_loss': 5.406, 'ppl': 222.7, 'total_skipped_batches': 193}
# [ time:10753.0s total_exs:334288 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20700, 'gnorm': 1.269, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.47, 'token_acc': 0.2016, 'nll_loss': 5.41, 'ppl': 223.6, 'total_skipped_batches': 193}
# [ time:10756.0s total_exs:334384 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20706, 'gnorm': 1.218, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.06, 'token_acc': 0.2198, 'nll_loss': 5.175, 'ppl': 176.9, 'total_skipped_batches': 193}
# [ time:10758.0s total_exs:334464 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20711, 'gnorm': 1.189, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 25.91, 'token_acc': 0.2341, 'nll_loss': 5.196, 'ppl': 180.6, 'total_skipped_batches': 193}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:10760.0s total_exs:334560 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20716, 'gnorm': 1.306, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.41, 'token_acc': 0.2157, 'nll_loss': 5.484, 'ppl': 240.9, 'total_skipped_batches': 194}
# [ time:10762.0s total_exs:334656 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20722, 'gnorm': 1.339, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.28, 'token_acc': 0.218, 'nll_loss': 5.39, 'ppl': 219.2, 'total_skipped_batches': 194}
# [ time:10765.0s total_exs:334752 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20728, 'gnorm': 1.23, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.59, 'token_acc': 0.2192, 'nll_loss': 5.253, 'ppl': 191.2, 'total_skipped_batches': 194}
# [ time:10767.0s total_exs:334848 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20734, 'gnorm': 1.284, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.11, 'token_acc': 0.2153, 'nll_loss': 5.19, 'ppl': 179.5, 'total_skipped_batches': 194}
# [ time:10769.0s total_exs:334944 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20740, 'gnorm': 1.249, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.39, 'token_acc': 0.2207, 'nll_loss': 5.225, 'ppl': 185.9, 'total_skipped_batches': 194}
# | WARNING: ran out of memory, skipping batch. if this happens frequently, decrease batchsize or truncate the inputs to the model.
# [ time:10772.0s total_exs:335040 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20745, 'gnorm': 1.279, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.22, 'token_acc': 0.2296, 'nll_loss': 5.109, 'ppl': 165.5, 'total_skipped_batches': 195}
# [ time:10774.0s total_exs:335136 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20751, 'gnorm': 1.312, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.68, 'token_acc': 0.2207, 'nll_loss': 5.278, 'ppl': 196.0, 'total_skipped_batches': 195}
# [ time:10776.0s total_exs:335232 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20757, 'gnorm': 1.362, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.76, 'token_acc': 0.1946, 'nll_loss': 5.447, 'ppl': 232.1, 'total_skipped_batches': 195}
# [ time:10779.0s total_exs:335328 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20763, 'gnorm': 1.29, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 33.3, 'token_acc': 0.1935, 'nll_loss': 5.533, 'ppl': 253.0, 'total_skipped_batches': 195}
# [ time:10781.0s total_exs:335408 epochs:0.13 ] {'exs': 80, 'lr': 0.001, 'total_train_updates': 20768, 'gnorm': 1.236, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 26.31, 'token_acc': 0.2421, 'nll_loss': 5.25, 'ppl': 190.6, 'total_skipped_batches': 195}
# [ time:10783.0s total_exs:335504 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20774, 'gnorm': 1.213, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 30.31, 'token_acc': 0.24, 'nll_loss': 5.049, 'ppl': 155.8, 'total_skipped_batches': 195}
# [ time:10785.0s total_exs:335600 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20780, 'gnorm': 1.334, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 33.2, 'token_acc': 0.2107, 'nll_loss': 5.512, 'ppl': 247.7, 'total_skipped_batches': 195}
# [ time:10788.0s total_exs:335696 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20786, 'gnorm': 1.183, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 31.69, 'token_acc': 0.2071, 'nll_loss': 5.282, 'ppl': 196.8, 'total_skipped_batches': 195}
# [ time:10790.0s total_exs:335792 epochs:0.13 ] {'exs': 96, 'lr': 0.001, 'total_train_updates': 20792, 'gnorm': 1.213, 'clip': 1.0, 'gpu_mem_percent': 1.34, 'loss': 32.24, 'token_acc': 0.2205, 'nll_loss': 5.361, 'ppl': 213.0, 'total_skipped_batches': 195}
# [ saving model checkpoint: models/HW2_model3.checkpoint
# [ max_train_time elapsed:10894.150842428207s ]
# [creating task(s): twitter]
# [loading parlAI text data:/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data/Twitter/valid.txt]
# [ running eval: valid ]
# /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/metrics.py:275: UserWarning: ROUGE requires nltk punkt tokenizer. Please run `python -c "import nltk; nltk.download('punkt')`
#   'ROUGE requires nltk punkt tokenizer. Please run '
# Traceback (most recent call last):
#   File "train_model.py", line 17, in <module>
#     TrainLoop(opt).train()
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/scripts/train_model.py", line 783, in train
#     v_report = run_eval(valid_worlds, opt, 'valid', max_exs, write_log=True)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/scripts/train_model.py", line 289, in run_eval
#     task_report = _run_single_eval(opt, v_world, max_exs / len(valid_worlds))
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/scripts/train_model.py", line 254, in _run_single_eval
#     valid_world.parley()
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/worlds.py", line 893, in parley
#     obs = self.batch_observe(other_index, batch_act, agent_idx)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/worlds.py", line 834, in batch_observe
#     observation = agents[index].observe(observation)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/teachers.py", line 450, in observe
#     self.metrics.evaluate_response(observation, self.lastY)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/metrics.py", line 532, in evaluate_response
#     self.add('rouge-1', r1)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/metrics.py", line 420, in add
#     self._metrics[key] = self._metrics.get(key) + value
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
torch.save('models/HW2_model2.checkpoint', path)

# %%
# !python3 eval_model.py -m seq2seq -t twitter -mf models/HW2_model3
# Out:
# [ Using CUDA ]
# Dictionary: loading dictionary from models/HW2_model3.dict
# [ num words =  366522 ]
# tcmalloc: large alloc 2635227136 bytes == 0x66f56000 @  0x7f0d74417b6b 0x7f0d74437379 0x7f0d1c70ab4a 0x7f0d1c70c5fa 0x7f0d1ee0f4af 0x7f0d1ee0f56d 0x7f0d6788a1c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Initialized embeddings for 175884 tokens (48.0%) from glove.
# tcmalloc: large alloc 2635227136 bytes == 0x66f56000 @  0x7f0d74417b6b 0x7f0d74437379 0x7f0d1c70ab4a 0x7f0d1c70c5fa 0x7f0d1ee0f4af 0x7f0d1ee0f56d 0x7f0d6788a1c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Total parameters: 332704926
# Trainable parameters:  332704926
# [ Loading existing model params from models/HW2_model3 ]
# [ optional arguments: ]
# [  aggregate_micro: False ]
# [  display_examples: False ]
# [  log_every_n_secs: 2 ]
# [  metrics: all ]
# [  num_examples: -1 ]
# [  report_filename:  ]
# [  save_world_logs: False ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 16 ]
# [  datapath: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data ]
# [  datatype: train ]
# [  download_path: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/downloads ]
# [  dynamic_batching: None ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: twitter ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: models/HW2_model3 ]
# [ World Logging: ]
# [  log_keep_fields: all ]
# [ Tensorboard Arguments: ]
# [  tensorboard_log: False ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: local ]
# [  attention_length: 48 ]
# [  attention_time: pre ]
# [  bidirectional: True ]
# [  decoder: same ]
# [  dropout: 0.3 ]
# [  embeddingsize: 300 ]
# [  hiddensize: 128 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 4 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: -1 ]
# [  beam_context_block_ngram: -1 ]
# [  beam_length_penalty: 0.65 ]
# [  beam_min_length: 1 ]
# [  beam_size: 40 ]
# [  compute_tokenized_bleu: False ]
# [  inference: beam ]
# [  skip_generation: False ]
# [  topk: 10 ]
# [  topp: 0.9 ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: glove ]
# [  force_fp16_tokens: False ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: False ]
# [  label_truncate: None ]
# [  no_cuda: False ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: [0.9, 0.999] ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 0.001 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: [0.7] ]
# [  optimizer: adam ]
# [  weight_decay: None ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: models/HW2_model3.dict ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Learning Rate Scheduler: ]
# [  invsqrt_lr_decay_gamma: -1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  max_lr_steps: -1 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ Evaluating task twitter using datatype valid. ]
# [creating task(s): twitter]
# [loading parlAI text data:/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data/Twitter/valid.txt]
# 36s elapsed: {'exs': 1, '%done': '0.01%', 'time_left': '378388s', 'accuracy': 0.0, 'f1': 0.10714285714285712, 'bleu-4': 0.028570780729954972, 'lr': 0.001, 'total_train_updates': 20795, 'gpu_mem_percent': 0.685, 'loss': 3.817, 'token_acc': 0.3077, 'nll_loss': 3.817, 'ppl': 45.47}
# 68s elapsed: {'exs': 2, '%done': '0.02%', 'time_left': '357032s', 'accuracy': 0.0, 'f1': 0.05357142857142856, 'bleu-4': 0.014285390364977486, 'lr': 0.001, 'total_train_updates': 20795, 'gpu_mem_percent': 0.689, 'loss': 8.17, 'token_acc': 0.2857, 'nll_loss': 4.104, 'ppl': 60.59}
# 99s elapsed: {'exs': 3, '%done': '0.03%', 'time_left': '345373s', 'accuracy': 0.0, 'f1': 0.04404761904761904, 'bleu-4': 0.009523593581664897, 'lr': 0.001, 'total_train_updates': 20795, 'gpu_mem_percent': 0.689, 'loss': 11.68, 'token_acc': 0.3261, 'nll_loss': 3.874, 'ppl': 48.11}
# Traceback (most recent call last):
#   File "eval_model.py", line 18, in <module>
#     eval_model(opt, print_parser=parser)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/scripts/eval_model.py", line 175, in eval_model
#     task_report = _eval_single_world(opt, agent, task)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/scripts/eval_model.py", line 118, in _eval_single_world
#     world.parley()
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/worlds.py", line 344, in parley
#     acts[1] = agents[1].act()
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_agent.py", line 1696, in act
#     response = self.batch_act([self.observation])[0]
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_agent.py", line 1730, in batch_act
#     output = self.eval_step(batch)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_generator_agent.py", line 787, in eval_step
#     beam_preds_scores, _ = self._generate(batch, self.beam_size, maxlen)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_generator_agent.py", line 943, in _generate
#     b.advance(score[i])
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_generator_agent.py", line 1168, in advance
#     for i in range(self.beam_size)
#   File "/usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/parlai/core/torch_generator_agent.py", line 1168, in <listcomp>
#     for i in range(self.beam_size)
# KeyboardInterrupt

# %%
# !python3 interactive.py -m seq2seq -mf models/HW2_model3
# Out:
# [ optional arguments: ]
# [  display_examples: False ]
# [  display_ignore_fields: label_candidates,text_candidates ]
# [  display_prettify: False ]
# [  interactive_task: True ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data ]
# [  datatype: train ]
# [  download_path: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/downloads ]
# [  dynamic_batching: None ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: interactive ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: models/HW2_model3 ]
# [ Local Human Arguments: ]
# [  local_human_candidates_file: None ]
# [  single_turn: False ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: none ]
# [  attention_length: 48 ]
# [  attention_time: post ]
# [  bidirectional: False ]
# [  decoder: same ]
# [  dropout: 0.1 ]
# [  embeddingsize: 128 ]
# [  hiddensize: 128 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 2 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: -1 ]
# [  beam_context_block_ngram: -1 ]
# [  beam_length_penalty: 0.65 ]
# [  beam_min_length: 1 ]
# [  beam_size: 1 ]
# [  compute_tokenized_bleu: False ]
# [  inference: greedy ]
# [  skip_generation: False ]
# [  topk: 10 ]
# [  topp: 0.9 ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: random ]
# [  force_fp16_tokens: False ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: True ]
# [  label_truncate: None ]
# [  no_cuda: False ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: (0.9, 0.999) ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 1 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: (0.7,) ]
# [  optimizer: sgd ]
# [  weight_decay: None ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: None ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Learning Rate Scheduler: ]
# [  invsqrt_lr_decay_gamma: -1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  max_lr_steps: -1 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ Using CUDA ]
# Dictionary: loading dictionary from models/HW2_model3.dict
# [ num words =  366522 ]
# [Seq2seq: full interactive mode on.]
# tcmalloc: large alloc 2635227136 bytes == 0x66f36000 @  0x7fc321c41b6b 0x7fc321c61379 0x7fc2c9f34b4a 0x7fc2c9f365fa 0x7fc2cc6394af 0x7fc2cc63956d 0x7fc3150b41c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Initialized embeddings for 175884 tokens (48.0%) from glove.
# tcmalloc: large alloc 2635227136 bytes == 0x66f36000 @  0x7fc321c41b6b 0x7fc321c61379 0x7fc2c9f34b4a 0x7fc2c9f365fa 0x7fc2cc6394af 0x7fc2cc63956d 0x7fc3150b41c0 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x5a55a1 0x5a58f8 0x4e07ee 0x50abe1 0x50c5b9 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# Total parameters: 332704926
# Trainable parameters:  332704926
# [ Loading existing model params from models/HW2_model3 ]
# Enter [DONE] if you want to end the episode.
#
# [creating task(s): interactive]
# [ optional arguments: ]
# [  display_examples: False ]
# [  display_ignore_fields: label_candidates,text_candidates ]
# [  display_prettify: False ]
# [  interactive_task: True ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 16 ]
# [  datapath: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/data ]
# [  datatype: train ]
# [  download_path: /usr/local/lib/python3.6/dist-packages/parlai-0.1.0-py3.6.egg/downloads ]
# [  dynamic_batching: None ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: twitter ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: models/HW2_model3 ]
# [ Local Human Arguments: ]
# [  local_human_candidates_file: None ]
# [  single_turn: False ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: local ]
# [  attention_length: 48 ]
# [  attention_time: pre ]
# [  bidirectional: True ]
# [  decoder: same ]
# [  dropout: 0.3 ]
# [  embeddingsize: 300 ]
# [  hiddensize: 128 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 4 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: -1 ]
# [  beam_context_block_ngram: -1 ]
# [  beam_length_penalty: 0.65 ]
# [  beam_min_length: 1 ]
# [  beam_size: 40 ]
# [  compute_tokenized_bleu: False ]
# [  inference: beam ]
# [  skip_generation: False ]
# [  topk: 10 ]
# [  topp: 0.9 ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: glove ]
# [  force_fp16_tokens: False ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: True ]
# [  label_truncate: None ]
# [  no_cuda: False ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: [0.9, 0.999] ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 0.001 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: [0.7] ]
# [  optimizer: adam ]
# [  weight_decay: None ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: models/HW2_model3.dict ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Learning Rate Scheduler: ]
# [  invsqrt_lr_decay_gamma: -1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  max_lr_steps: -1 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# Enter Your Message: What's up?
# [Seq2Seq]: thank you so much ! ! ! ! @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ]
# Enter Your Message: Tragedy buddy! This is tragedy.
# [Seq2Seq]: thank you so much @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ]
# Enter Your Message: <<<<<>>>>>> <<<??<>>>
# [Seq2Seq]: thank you so much @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ]
# Enter Your Message: Aloha!
# [Seq2Seq]: thank you so much @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ]
# Enter Your Message: rubbishy rubbishy rubishhhhh
# [Seq2Seq]: thank you so much @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ] @ red_heart @ [ ? ]
# Enter Your Message:

# %%
cp models/HW2_model3 /content/gdrive/'My Drive'/HW2_model3

# %%
cp models/HW2_model3.dict /content/gdrive/'My Drive'/HW2_model3.dict

# %%
cp models/HW2_model3.trainstats /content/gdrive/'My Drive'/HW2_model3.trainstats

# %%
# %ls
# Out:
# base_train.py     extract_image_feature.py  remote.py
# build_dict.py     interactive.py            seq2seq_train_babi.py
# display_data.py   models/                   train_model.py
# display_model.py  profile_train.py
# eval_model.py     README.md
